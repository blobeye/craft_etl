# %%
import cda2
import json
import re
import pyspark.sql.types as T
import pyspark.sql.functions as F
#import datetime
import time

from datetime import datetime, timedelta
from timeit import default_timer as timer
from pyspark.sql.window import Window
from pyspark.sql.functions import col, row_number

# %% [markdown]
# # Connect to Spark

# %%
api = cda2.Api()

# %% [markdown]
# Set configuration parameters to better optimize queries.

# %%
config = {
    "spark.sql.adaptive.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.parallelismFirst": "false",
    "spark.sql.adaptive.coalescePartitions.minPartitionSize": "1m",
    "spark.executor.memory": "8g",
    "spark.executor.memoryOverhead": "16g",
}

# %% [markdown]
# Start Spark and specify number of cpus to use. 400 is quite high, but we'll be running 1 year at a time and want to have it done in just a few minutes.

# %%
api.start_spark(n_executors=400, config=config)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/11/14 22:00:55 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/11/14 22:01:00 WARN DomainSocketFactory: The short-circuit local reads feature cannot be used because libhadoop cannot be loaded.
# 23/11/14 22:01:10 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Attempted to request executors before the AM has registered!

# %%
year0 = "2019"
year1 = str(int(year0) + 1)

# %%
datelist = [
    year0 + "0101",
    year0 + "0701",
    year1 + "0101",
]

datelist = [
    year0 + "0101",
    year0 + "0301",
    year0 + "0501",
    year0 + "0701",
    year0 + "0901",
    year0 + "1101",
    year1 + "0101",
]

datelist = [
    year0 + "0101",
    year0 + "0401",
    year0 + "0701",
    year0 + "1001",
    year0 + "1101",
    year0 + "1201",
    year1 + "0101",
]

datelist = [
    year0 + "0101",
    year0 + "0201",
    year0 + "0301",
    year0 + "0401",
    year0 + "0501",
    year0 + "0601",
    year0 + "0701",
    year0 + "0801",
    year0 + "0901",
    year0 + "1001",
    year0 + "1101",
    year0 + "1201",
    year1 + "0101",
]

# %%
i = 0;

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
# Out:
# start time:  2023-11-14 22:01:29.542863
# starting:  {'start_date': '20190101', 'end_date': '20190201'}
#    retrieving litetracks
# Could not find data for: 2019-01-30
#    retrieving planned_routes
# Multiple versions found: 3.1.12.2, 3.1.22
#    retrieving flightplans
#    retrieving airspace_assignments
#    joining dataframes
#    creating master dataframe
#    started saving litetracks
#                                                                                 ]0]
#    completed saving litetracks
#    started saving flightplans
#                                                                                 ]]]
#    completed saving flightplans
#    started saving airspace_assignments
#                                                                                 00]]]
#    completed saving airspace_assignments
# end time:  2023-11-14 22:17:45.604081

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
# Out:
# start time:  2023-11-14 22:17:45.619097
# starting:  {'start_date': '20190201', 'end_date': '20190301'}
#    retrieving litetracks
# Could not find data for: 2019-02-14
# Multiple versions found: 3.1.27, 3.1.30
#    retrieving planned_routes
# Multiple versions found: 3.1.12.2, 3.1.22
#    retrieving flightplans
#    retrieving airspace_assignments
#    joining dataframes
#    creating master dataframe
#    started saving litetracks
#                                                                                 1]]]]]]
#    completed saving litetracks
#    started saving flightplans
#                                                                                 1]]]]]0]
#    completed saving flightplans
#    started saving airspace_assignments
#                                                                                 00]]0]]
#    completed saving airspace_assignments
# end time:  2023-11-14 22:27:46.874982

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
# Out:
# start time:  2023-11-14 22:27:46.883295
# starting:  {'start_date': '20190301', 'end_date': '20190401'}
#    retrieving litetracks
#    retrieving planned_routes
# Multiple versions found: 3.1.12.2, 3.1.22
# Multiple versions found: 3.1.24, 3.1.34
#    retrieving flightplans
# Multiple versions found: 3.1.20, 3.1.34
#    retrieving airspace_assignments
# Multiple versions found: 3.1.15.1, 3.1.34
#    joining dataframes
#    creating master dataframe
#    started saving litetracks
#                                                                                 ]]00]]]
#    completed saving litetracks
#    started saving flightplans
#                                                                                 ] 1]]]
#    completed saving flightplans
#    started saving airspace_assignments
#                                                                                 ]]]0]]]
#    completed saving airspace_assignments
# end time:  2023-11-14 22:38:56.353290

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
# Out:
# start time:  2023-11-14 22:38:56.364719
# starting:  {'start_date': '20190401', 'end_date': '20190501'}
#    retrieving litetracks
#    retrieving planned_routes
# Multiple versions found: 3.1.12.2, 3.1.22
#    retrieving flightplans
#    retrieving airspace_assignments
# Multiple versions found: 3.1.14, 3.1.15.1
#    joining dataframes
#    creating master dataframe
#    started saving litetracks
#                                                                                 600]]]]
#    completed saving litetracks
#    started saving flightplans
#                                                                                  1]00]]
#    completed saving flightplans
#    started saving airspace_assignments
#                                                                                 00]]0]]
#    completed saving airspace_assignments
# end time:  2023-11-14 22:48:48.386037

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
# Out:
# start time:  2023-11-14 22:48:48.398677
# starting:  {'start_date': '20190501', 'end_date': '20190601'}
#    retrieving litetracks
#    retrieving planned_routes
# Multiple versions found: 3.1.12.2, 3.1.22
#    retrieving flightplans
#    retrieving airspace_assignments
#    joining dataframes
#    creating master dataframe
#    started saving litetracks
#                                                                                 1]190]]00]
#    completed saving litetracks
#    started saving flightplans
#                                                                                 ]1]600]]]]
#    completed saving flightplans
#    started saving airspace_assignments
#                                                                                 ]]190]00]]
#    completed saving airspace_assignments
# end time:  2023-11-14 22:57:58.548259

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
# Out:
# start time:  2023-11-14 22:57:58.560902
# starting:  {'start_date': '20190601', 'end_date': '20190701'}
#    retrieving litetracks
#    retrieving planned_routes
# Multiple versions found: 3.1.12.2, 3.1.22
#    retrieving flightplans
# Multiple versions found: 3.1.20, 3.1.61
#    retrieving airspace_assignments
#    joining dataframes
#    creating master dataframe
#    started saving litetracks
#                                                                                  1600]0]]]
#    completed saving litetracks
#    started saving flightplans
#                                                                                  1600]0]0]
#    completed saving flightplans
#    started saving airspace_assignments
#                                                                                 / 1]6]0]]]
#    completed saving airspace_assignments
# end time:  2023-11-14 23:07:32.305844

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
# Out:
# start time:  2023-11-14 23:07:32.318531
# starting:  {'start_date': '20190701', 'end_date': '20190801'}
#    retrieving litetracks
#    retrieving planned_routes
# Multiple versions found: 3.1.12.2, 3.1.22
#    retrieving flightplans
# Multiple versions found: 3.1.20, 3.1.61
#    retrieving airspace_assignments
# Multiple versions found: 3.1.15.1, 3.1.62
#    joining dataframes
#    creating master dataframe
#    started saving litetracks
#                                                                                 1]600]]0]]
#    completed saving litetracks
#    started saving flightplans
#                                                                                 / 1]00]0]]
#    completed saving flightplans
#    started saving airspace_assignments
#                                                                                 ]]]600]]]
#    completed saving airspace_assignments
# end time:  2023-11-14 23:16:49.808683

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
# Out:
# start time:  2023-11-14 23:16:49.821886
# starting:  {'start_date': '20190801', 'end_date': '20190901'}
#    retrieving litetracks
#    retrieving planned_routes
# Multiple versions found: 3.1.12.2, 3.1.22
# Multiple versions found: 3.1.24, 3.1.40
#    retrieving flightplans
# Multiple versions found: 3.1.20, 3.1.61
#    retrieving airspace_assignments
#    joining dataframes
#    creating master dataframe
#    started saving litetracks
#                                                                                 / 1]600]]]
#    completed saving litetracks
#    started saving flightplans
#                                                                                 ] 1600]0]
#    completed saving flightplans
#    started saving airspace_assignments
#                                                                                 / 1]]0]0]
#    completed saving airspace_assignments
# end time:  2023-11-14 23:26:55.370002

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
# Out:
# start time:  2023-11-14 23:26:55.407507
# starting:  {'start_date': '20190901', 'end_date': '20191001'}
#    retrieving litetracks
#    retrieving planned_routes
# Multiple versions found: 3.1.12.2, 3.1.22
#    retrieving flightplans
#    retrieving airspace_assignments
#    joining dataframes
#    creating master dataframe
#    started saving litetracks
#                                                                                 1]600]]]]]
#    completed saving litetracks
#    started saving flightplans
#                                                                                 / 1]6]]0]
#    completed saving flightplans
#    started saving airspace_assignments
#                                                                                 1]1]56]0]]
#    completed saving airspace_assignments
# end time:  2023-11-14 23:36:21.497835

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
# Out:
# start time:  2023-11-14 23:36:21.509623
# starting:  {'start_date': '20191001', 'end_date': '20191101'}
#    retrieving litetracks
#    retrieving planned_routes
# Multiple versions found: 3.1.12.2, 3.1.22
# Multiple versions found: 3.1.24, 3.1.40
#    retrieving flightplans
#    retrieving airspace_assignments
#    joining dataframes
#    creating master dataframe
#    started saving litetracks
#                                                                                 / 1]0]]0]]
#    completed saving litetracks
#    started saving flightplans
#                                                                                  / 1]]00]]
#    completed saving flightplans
#    started saving airspace_assignments
#                                                                                 / 1]]3]]]]
#    completed saving airspace_assignments
# end time:  2023-11-14 23:46:35.566038

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
# Out:
# start time:  2023-11-14 23:46:35.579007
# starting:  {'start_date': '20191101', 'end_date': '20191201'}
#    retrieving litetracks
#    retrieving planned_routes
# Multiple versions found: 3.1.12.2, 3.1.22
#    retrieving flightplans
#    retrieving airspace_assignments
#    joining dataframes
#    creating master dataframe
#    started saving litetracks
#                                                                                 / 1]3]]]0]
#    completed saving litetracks
#    started saving flightplans
#                                                                                 ]/ 1]]]00]
#    completed saving flightplans
#    started saving airspace_assignments
#                                                                                 6]1]600]0]
#    completed saving airspace_assignments
# end time:  2023-11-14 23:56:43.115495

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
# Out:
# start time:  2023-11-14 23:56:43.129122
# starting:  {'start_date': '20191201', 'end_date': '20200101'}
#    retrieving litetracks
#    retrieving planned_routes
# Multiple versions found: 3.1.12.2, 3.1.22
#    retrieving flightplans
#    retrieving airspace_assignments
#    joining dataframes
#    creating master dataframe
#    started saving litetracks
#                                                                                 / 1]8]]]]]
#    completed saving litetracks
#    started saving flightplans
#                                                                                 ]/ 1]0]]]
#    completed saving flightplans
#    started saving airspace_assignments
#                                                                                 ]/ 1600]]]
#    completed saving airspace_assignments
# end time:  2023-11-15 00:06:46.031333

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
