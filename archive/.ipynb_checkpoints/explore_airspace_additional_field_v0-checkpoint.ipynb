# %% [markdown]
# # Imports

# %%
import re
import cda2
import math

import time
from datetime import datetime, timedelta

import pandas as pd
import pyarrow
from typing import Iterator, Tuple
from pyspark.sql.functions import pandas_udf

from pyspark.sql.window import Window
import pyspark.sql.types as T
import pyspark.sql.functions as F
from pyspark.sql.functions import col, row_number
from pyspark.sql.functions import explode, map_keys, col

# %%
api = cda2.Api()

# %%
# Set configuration parameters to better optimize queries.

config = {
    "spark.sql.adaptive.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.parallelismFirst": "false",
    "spark.sql.adaptive.coalescePartitions.minPartitionSize": "1m",
    "spark.executor.memory": "8g",
    "spark.executor.memoryOverhead": "16g",
}

# %%
# Start Spark and specify number of cpus to use.

api.start_spark(n_executors=100, config=config)
# Out:
# https://artifacts.mitre.org/artifactory/java-libs-release added as a remote repository with the name: repo-1
# https://dali.mitre.org/nexus/content/repositories/mitre-caasd-releases added as a remote repository with the name: repo-2
# https://dali.mitre.org/nexus/content/repositories/external-releases added as a remote repository with the name: repo-3
# Ivy Default Cache set to: /home/rchong/.ivy2/cache
# The jars for the packages stored in: /home/rchong/.ivy2/jars
# org.mitre.spark#spark-geo_spark3.5_2.12 added as a dependency
# org.apache.spark#spark-avro_2.12 added as a dependency
# graphframes#graphframes added as a dependency
# org.mongodb.spark#mongo-spark-connector_2.12 added as a dependency
# com.oracle.database.jdbc#ojdbc8 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-2665fe33-0b42-4dca-abfd-1ec0060f394c;1.0
# 	confs: [default]
# :: loading settings :: url = jar:file:/devel/data_access/software/tdp-jupyter/poetry/cache/virtualenvs/python39-QwwvzYkJ-py3.9/lib/python3.9/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 	found org.mitre.spark#spark-geo_spark3.5_2.12;0.2.0 in repo-1
# 	found org.mitre.spark#spark-geo-core_2.12;0.2.0 in repo-1
# 	found org.scala-lang.modules#scala-collection-compat_2.12;2.11.0 in central
# 	found net.sf.geographiclib#GeographicLib-Java;2.0 in central
# 	found org.ejml#ejml-core;0.43.1 in central
# 	found org.ejml#ejml-ddense;0.43.1 in central
# 	found com.esri.geometry#esri-geometry-api;2.2.4 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.9.6 in central
# 	found com.google.geometry#s2-geometry;2.0.0 in central
# 	found com.google.guava#guava;25.1-jre in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found org.checkerframework#checker-qual;2.0.0 in central
# 	found com.google.errorprone#error_prone_annotations;2.1.3 in central
# 	found com.google.j2objc#j2objc-annotations;1.1 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.14 in central
# 	found com.uber#h3;4.1.1 in central
# 	found org.apache.spark#spark-avro_2.12;3.5.1 in central
# 	found org.tukaani#xz;1.9 in central
# 	found graphframes#graphframes;0.8.3-spark3.5-s_2.12 in spark-packages
# 	found org.slf4j#slf4j-api;1.7.16 in central
# 	found org.mongodb.spark#mongo-spark-connector_2.12;10.3.0 in central
# 	found org.mongodb#mongodb-driver-sync;4.8.2 in central
# 	[4.8.2] org.mongodb#mongodb-driver-sync;[4.8.1,4.8.99)
# 	found org.mongodb#bson;4.8.2 in central
# 	found org.mongodb#mongodb-driver-core;4.8.2 in central
# 	found org.mongodb#bson-record-codec;4.8.2 in central
# 	found com.oracle.database.jdbc#ojdbc8;23.4.0.24.05 in central
# :: resolution report :: resolve 3159ms :: artifacts dl 38ms
# 	:: modules in use:
# 	com.esri.geometry#esri-geometry-api;2.2.4 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.9.6 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.errorprone#error_prone_annotations;2.1.3 from central in [default]
# 	com.google.geometry#s2-geometry;2.0.0 from central in [default]
# 	com.google.guava#guava;25.1-jre from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.1 from central in [default]
# 	com.oracle.database.jdbc#ojdbc8;23.4.0.24.05 from central in [default]
# 	com.uber#h3;4.1.1 from central in [default]
# 	graphframes#graphframes;0.8.3-spark3.5-s_2.12 from spark-packages in [default]
# 	net.sf.geographiclib#GeographicLib-Java;2.0 from central in [default]
# 	org.apache.spark#spark-avro_2.12;3.5.1 from central in [default]
# 	org.checkerframework#checker-qual;2.0.0 from central in [default]
# 	org.codehaus.mojo#animal-sniffer-annotations;1.14 from central in [default]
# 	org.ejml#ejml-core;0.43.1 from central in [default]
# 	org.ejml#ejml-ddense;0.43.1 from central in [default]
# 	org.mitre.spark#spark-geo-core_2.12;0.2.0 from repo-1 in [default]
# 	org.mitre.spark#spark-geo_spark3.5_2.12;0.2.0 from repo-1 in [default]
# 	org.mongodb#bson;4.8.2 from central in [default]
# 	org.mongodb#bson-record-codec;4.8.2 from central in [default]
# 	org.mongodb#mongodb-driver-core;4.8.2 from central in [default]
# 	org.mongodb#mongodb-driver-sync;4.8.2 from central in [default]
# 	org.mongodb.spark#mongo-spark-connector_2.12;10.3.0 from central in [default]
# 	org.scala-lang.modules#scala-collection-compat_2.12;2.11.0 from central in [default]
# 	org.slf4j#slf4j-api;1.7.16 from central in [default]
# 	org.tukaani#xz;1.9 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   26  |   1   |   0   |   0   ||   26  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-2665fe33-0b42-4dca-abfd-1ec0060f394c
# 	confs: [default]
# 	0 artifacts copied, 26 already retrieved (0kB/15ms)
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Setting Spark log level to "ERROR".

# %%
year0 = "2025"
year1 = str(int(year0) + 1)

# %%
dates = {"start_date": year0 + "-01-01", "end_date": year1 +"-01-01"}

# %% [markdown]
# # retrieve faa

# %%
df_airspaces = (
    api.dataframe("StaticEramAirspace",
                  **dates,
#                  partition_filters=api.custom_partitions(['ARTCC_SECTOR']), // additional: {FULLNAME -> SECT1} 
#                  partition_filters=api.custom_partitions(['SECTOR']), // additional: {ACTIVE -> false} or {ACTIVE -> true}
#                  partition_filters=api.custom_partitions(['TRACON']), // additional: {}
#                  partition_filters=api.custom_partitions(['SAA']), // additional: {ACTIVE -> ALWAYS_OFF, TYPE -> LOCAL_ASSIGNED}
#                  partition_filters=api.custom_partitions(['FAV']), # additional: {TYPE -> ENROUTE} ; {TYPE -> APPROACH, ARTSID -> MCI} ; 
#                  partition_filters=api.custom_partitions(['ZDC']),
                  partition_filters=api.custom_partitions(['ZAB', 'SECTOR']),
                  metadata=True)
    .select (
        "center",
        "type",
        "identifier",
        "additional",
        F.explode('geometry.modules').alias('module'),
        "chart_date"
    )
    .withColumnRenamed('center', 'artcc')
    .withColumnRenamed('identifier', 'tracon')
    .withColumn("grouping", F.concat("artcc", F.lit("_"), "tracon", F.lit("_"), "module.identifier"))
    .orderBy("grouping")
)
# Out:
# Multiple versions found: 3.1.71, 3.1.73, 3.1.74, 3.1.76, 3.1.77, 3.1.79

# %%
#df_airspaces = (df_airspaces
#    .filter(col("row") != null)
#    .withColumn("tracon_type", df_airspaces["additional"].getItem("TYPE"))
##    .withColumn("tracon", df_airspaces["additional"].getItem("ARTSID"))
#    .withColumn("tracon", F.coalesce(df_airspaces["additional"].getItem("ARTSID"), F.lit("")))
##    .drop("additional")
#    .withColumn("tracon_artsid", F.coalesce(df_airspaces["additional"].getItem("ARTSID")))
#    .withColumn("tracon_aci", F.coalesce(df_airspaces["additional"].getItem("APPROACH_CONTROL_ID")))
#)

#window = Window.partitionBy("grouping").orderBy(col("end_date").desc())
#window = Window.partitionBy("grouping").orderBy(col("metadata.effective_end_date").desc())
window = Window.partitionBy("grouping").orderBy(col("chart_date").desc())

df_airspaces = (df_airspaces
    .withColumn("row", row_number().over(window))
    .withColumn("tracon_type", df_airspaces["additional"].getItem("TYPE"))
    .withColumn("tracon_artsid", F.coalesce(df_airspaces["additional"].getItem("ARTSID")))
    .withColumn("tracon_aci", F.coalesce(df_airspaces["additional"].getItem("APPROACH_CONTROL_ID")))
    .filter(col("row") == 1)
    .drop("row", "chart_date")
    .orderBy("grouping")
)

# %%
df_airspaces.count()
# Out:
# 79

# %%
df_airspaces.show(79)
# Out:
# [Stage 22:>                                                         (0 + 1) / 1]
# +-----+------+------+----------+--------------------+----------------+-----------+-------------+----------+
# |artcc|  type|tracon|additional|              module|        grouping|tracon_type|tracon_artsid|tracon_aci|
# +-----+------+------+----------+--------------------+----------------+-----------+-------------+----------+
# |  ZAB|TRACON|   ABQ|        {}|{00201-1, {[{34.8...| ZAB_ABQ_00201-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ABQ|        {}|{00210-1, {[{34.8...| ZAB_ABQ_00210-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ABQ|        {}|{00217-1, {[{34.8...| ZAB_ABQ_00217-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ABQ|        {}|{00230-1, {[{35.1...| ZAB_ABQ_00230-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ABQ|        {}|{00231-1, {[{35.4...| ZAB_ABQ_00231-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ABQ|        {}|{00234-1, {[{35.1...| ZAB_ABQ_00234-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ABQ|        {}|{00236-1, {[{35.4...| ZAB_ABQ_00236-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ABQ|        {}|{00237-1, {[{35.3...| ZAB_ABQ_00237-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ABQ|        {}|{00240-1, {[{35.6...| ZAB_ABQ_00240-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ABQ|        {}|{00294-1, {[{34.8...| ZAB_ABQ_00294-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   AMA|        {}|{00601-1, {[{34.7...| ZAB_AMA_00601-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   AMA|        {}|{00601-2, {[{34.7...| ZAB_AMA_00601-2|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   CVS|        {}|{00801-1, {[{34.6...| ZAB_CVS_00801-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ELP|        {}|{00101-1, {[{31.7...| ZAB_ELP_00101-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ELP|        {}|{00131-1, {[{32.2...| ZAB_ELP_00131-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ELP|        {}|{00132-1, {[{31.7...| ZAB_ELP_00132-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   FHU|        {}|{02206-1, {[{31.3...| ZAB_FHU_02206-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   FHU|        {}|{02206-2, {[{31.3...| ZAB_FHU_02206-2|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   FHU|        {}|{02206-3, {[{31.3...| ZAB_FHU_02206-3|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   FHU|        {}|{02206-4, {[{31.3...| ZAB_FHU_02206-4|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   FHU|        {}|{02207-3, {[{31.8...| ZAB_FHU_02207-3|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   FHU|        {}|{02208-1, {[{31.8...| ZAB_FHU_02208-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00501-1, {[{33.2...| ZAB_LUF_00501-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00501-2, {[{33.4...| ZAB_LUF_00501-2|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00501-3, {[{33.4...| ZAB_LUF_00501-3|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00501-4, {[{33.2...| ZAB_LUF_00501-4|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00501-5, {[{33.4...| ZAB_LUF_00501-5|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00502-1, {[{33.3...| ZAB_LUF_00502-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00503-1, {[{33.8...| ZAB_LUF_00503-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00503-2, {[{33.8...| ZAB_LUF_00503-2|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00503-3, {[{33.8...| ZAB_LUF_00503-3|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00507-1, {[{33.5...| ZAB_LUF_00507-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00533-1, {[{33.7...| ZAB_LUF_00533-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00539-1, {[{33.5...| ZAB_LUF_00539-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00542-1, {[{33.0...| ZAB_LUF_00542-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00543-1, {[{33.7...| ZAB_LUF_00543-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00543-2, {[{33.7...| ZAB_LUF_00543-2|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00546-1, {[{33.0...| ZAB_LUF_00546-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00549-1, {[{33.5...| ZAB_LUF_00549-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   LUF|        {}|{00549-2, {[{33.5...| ZAB_LUF_00549-2|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00301-1, {[{33.7...| ZAB_PHX_00301-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00301-2, {[{33.7...| ZAB_PHX_00301-2|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00301-3, {[{33.7...| ZAB_PHX_00301-3|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00301-4, {[{33.7...| ZAB_PHX_00301-4|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00301-5, {[{33.7...| ZAB_PHX_00301-5|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00301-6, {[{33.7...| ZAB_PHX_00301-6|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00301-7, {[{33.9...| ZAB_PHX_00301-7|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00301-9, {[{33.4...| ZAB_PHX_00301-9|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00310-1, {[{34.0...| ZAB_PHX_00310-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00320-1, {[{34.0...| ZAB_PHX_00320-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00325-1, {[{34.0...| ZAB_PHX_00325-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00330-1, {[{34.6...| ZAB_PHX_00330-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00331-1, {[{35.0...| ZAB_PHX_00331-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00332-1, {[{34.9...| ZAB_PHX_00332-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00333-1, {[{34.8...| ZAB_PHX_00333-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00334-1, {[{34.4...| ZAB_PHX_00334-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00335-1, {[{34.0...| ZAB_PHX_00335-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00336-8, {[{33.7...| ZAB_PHX_00336-8|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00337-2, {[{33.0...| ZAB_PHX_00337-2|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00337-3, {[{33.3...| ZAB_PHX_00337-3|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00337-4, {[{33.0...| ZAB_PHX_00337-4|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00338-1, {[{33.0...| ZAB_PHX_00338-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00340-1, {[{34.9...| ZAB_PHX_00340-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00345-1, {[{35.0...| ZAB_PHX_00345-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00350-1, {[{34.8...| ZAB_PHX_00350-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   PHX|        {}|{00360-1, {[{34.6...| ZAB_PHX_00360-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ROW|        {}|{00901-1, {[{33.9...| ZAB_ROW_00901-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   ROW|        {}|{00902-1, {[{33.9...| ZAB_ROW_00902-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|  SAFT|        {}|{02401-1, {[{35.6...|ZAB_SAFT_02401-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   TUS|        {}|{00401-1, {[{32.3...| ZAB_TUS_00401-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   TUS|        {}|{00431-1, {[{31.8...| ZAB_TUS_00431-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   TUS|        {}|{00432-2, {[{32.3...| ZAB_TUS_00432-2|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   TUS|        {}|{00433-1, {[{32.5...| ZAB_TUS_00433-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   TUS|        {}|{00434-1, {[{32.5...| ZAB_TUS_00434-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   WSD|        {}|{00771-1, {[{33.7...| ZAB_WSD_00771-1|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   WSD|        {}|{00771-2, {[{33.7...| ZAB_WSD_00771-2|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   WSD|        {}|{00771-3, {[{33.7...| ZAB_WSD_00771-3|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   WSD|        {}|{00771-4, {[{33.7...| ZAB_WSD_00771-4|       NULL|         NULL|      NULL|
# |  ZAB|TRACON|   WSD|        {}|{00771-5, {[{33.5...| ZAB_WSD_00771-5|       NULL|         NULL|      NULL|
# +-----+------+------+----------+--------------------+----------------+-----------+-------------+----------+

# %%
df_airspaces_artsid = (df_airspaces
    .filter(col("tracon_artsid").isNotNull())
)

# %%
df_airspaces_artsid.count()

# %%
df_airspaces_artsid.show()

# %% [markdown]
# ## keep only the newest update

# %%
#window = Window.partitionBy("grouping").orderBy(col("end_date").desc())
#window = Window.partitionBy("grouping").orderBy(col("metadata.effective_end_date").desc())
window = Window.partitionBy("grouping").orderBy(col("chart_date").desc())

df_airspaces_newest = (df_airspaces
    .withColumn("row", row_number().over(window))
    .filter(col("row") == 1)
    .drop("row", "chart_date")
    .orderBy("grouping")
)

# %%
df_airspaces_newest.count()

# %%
df_airspaces_newest.select("additional").show(370, truncate=False)

# %%
module_schema = T.StructType([
    T.StructField("module", T.StructType([
        T.StructField("identifier", T.DoubleType(), True),
        T.StructField("floor", T.DoubleType(), True),
        T.StructField("ceiling", T.DoubleType(), True),
        T.StructField("polygon", T.StructType([
            T.StructField("boundary", T.ArrayType(
                T.StructType([
                    T.StructField("latitude", T.DoubleType(), True),
                    T.StructField("longitude", T.DoubleType(), True),
                    T.StructField("sequence_number", T.IntegerType(), True),
                ]), True), True),
        ]), True),
    ]), True),
])

# %%
none_string = "*"
separator_string = ":"

#@F.udf(T.StringType())
@F.udf(T.MapType(T.StringType(),T.StringType()))
def extract_boundary_from_module(module:module_schema) -> map:  
    result = {}

    result["shelf"] = f'{module.identifier}'
    result["floor"] = f'{module.floor:.0f}'
    result["ceiling"] = f'{module.ceiling:.0f}'

    boundary_string = ""

    module.polygon.boundary.sort(key=lambda x: x.sequence_number, reverse=False)

    for point in module.polygon.boundary:
        boundary_string += (none_string if point.latitude is None else f'{point.latitude:.6f}') + " "
        boundary_string += (none_string if point.longitude is None else f'{point.longitude:.6f}') + separator_string

    # drop the trailing separator
    if len(boundary_string) > 0:
        boundary_string = boundary_string[0:len(separator_string) * -1]

    result["boundary"] = boundary_string
    result["shelf"] = module.identifier

    return result

# %%
df_airspaces_dict = (
    df_airspaces_newest
    .withColumn("module_dict", extract_boundary_from_module("module"))
    .select(
        "center",
        "type",
        "fav_id",
        "fav_type",
        "tracon",
        "module_dict",
    )
    .drop("module")
    .orderBy("center", "type", "fav_id")
)

# %%
#df_tracons_dict.show(1, truncate=False)

# %%
# expand the dictionary to columns

# https://mungingdata.com/pyspark/dict-map-to-multiple-columns/
# https://stackoverflow.com/questions/36869134/pyspark-converting-a-column-of-type-map-to-multiple-columns-in-a-dataframe

keys = ["shelf", "ceiling", "floor", "boundary"]
key_cols = list(map(lambda f: F.col("module_dict").getItem(f).alias(str(f)), keys))
final_cols = [
        "center",
        "type",
        "fav_id",
        "fav_type",
        "tracon",
             ] + key_cols

# %%
df_airspaces_output = (
    df_airspaces_dict.select(final_cols)
)

# %%
#df_airspaces_output.show(10)

# %%
(
    df_airspaces_output
    .write.option("header", True)
    .csv("CRAFT/" + year0 + "/favs", compression="None", mode="overwrite")
)
