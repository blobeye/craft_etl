# %% [markdown]
# # Imports

# %%
import re
import cda2
import math

import time
from datetime import datetime, timedelta

import pandas as pd
import pyarrow
from typing import Iterator, Tuple
from pyspark.sql.functions import pandas_udf

from pyspark.sql.window import Window
import pyspark.sql.types as T
import pyspark.sql.functions as F
from pyspark.sql.functions import col, row_number
from pyspark.sql.functions import explode, map_keys, col

# %%
api = cda2.Api()

# %%
# Set configuration parameters to better optimize queries.

config = {
    "spark.sql.adaptive.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.parallelismFirst": "false",
    "spark.sql.adaptive.coalescePartitions.minPartitionSize": "1m",
    "spark.executor.memory": "8g",
    "spark.executor.memoryOverhead": "16g",
}

# %%
# Start Spark and specify number of cpus to use.

api.start_spark(n_executors=100, config=config)
# Out:
# https://artifacts.mitre.org/artifactory/java-libs-release added as a remote repository with the name: repo-1
# https://dali.mitre.org/nexus/content/repositories/mitre-caasd-releases added as a remote repository with the name: repo-2
# https://dali.mitre.org/nexus/content/repositories/external-releases added as a remote repository with the name: repo-3
# :: loading settings :: url = jar:file:/devel/data_access/software/tdp-jupyter/poetry/cache/virtualenvs/python39-QwwvzYkJ-py3.9/lib/python3.9/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/rchong/.ivy2/cache
# The jars for the packages stored in: /home/rchong/.ivy2/jars
# org.mitre.spark#spark-geo_spark3.5_2.12 added as a dependency
# org.apache.spark#spark-avro_2.12 added as a dependency
# graphframes#graphframes added as a dependency
# org.mongodb.spark#mongo-spark-connector_2.12 added as a dependency
# com.oracle.database.jdbc#ojdbc8 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-493695c5-1a15-4bd3-bb1b-d6dd2312213c;1.0
# 	confs: [default]
# 	found org.mitre.spark#spark-geo_spark3.5_2.12;0.2.0 in repo-1
# 	found org.mitre.spark#spark-geo-core_2.12;0.2.0 in repo-1
# 	found org.scala-lang.modules#scala-collection-compat_2.12;2.11.0 in central
# 	found net.sf.geographiclib#GeographicLib-Java;2.0 in central
# 	found org.ejml#ejml-core;0.43.1 in central
# 	found org.ejml#ejml-ddense;0.43.1 in central
# 	found com.esri.geometry#esri-geometry-api;2.2.4 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.9.6 in central
# 	found com.google.geometry#s2-geometry;2.0.0 in central
# 	found com.google.guava#guava;25.1-jre in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found org.checkerframework#checker-qual;2.0.0 in central
# 	found com.google.errorprone#error_prone_annotations;2.1.3 in central
# 	found com.google.j2objc#j2objc-annotations;1.1 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.14 in central
# 	found com.uber#h3;4.1.1 in central
# 	found org.apache.spark#spark-avro_2.12;3.5.1 in central
# 	found org.tukaani#xz;1.9 in central
# 	found graphframes#graphframes;0.8.3-spark3.5-s_2.12 in spark-packages
# 	found org.slf4j#slf4j-api;1.7.16 in central
# 	found org.mongodb.spark#mongo-spark-connector_2.12;10.3.0 in central
# 	found org.mongodb#mongodb-driver-sync;4.8.2 in central
# 	[4.8.2] org.mongodb#mongodb-driver-sync;[4.8.1,4.8.99)
# 	found org.mongodb#bson;4.8.2 in central
# 	found org.mongodb#mongodb-driver-core;4.8.2 in central
# 	found org.mongodb#bson-record-codec;4.8.2 in central
# 	found com.oracle.database.jdbc#ojdbc8;23.4.0.24.05 in central
# :: resolution report :: resolve 2057ms :: artifacts dl 49ms
# 	:: modules in use:
# 	com.esri.geometry#esri-geometry-api;2.2.4 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.9.6 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.errorprone#error_prone_annotations;2.1.3 from central in [default]
# 	com.google.geometry#s2-geometry;2.0.0 from central in [default]
# 	com.google.guava#guava;25.1-jre from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.1 from central in [default]
# 	com.oracle.database.jdbc#ojdbc8;23.4.0.24.05 from central in [default]
# 	com.uber#h3;4.1.1 from central in [default]
# 	graphframes#graphframes;0.8.3-spark3.5-s_2.12 from spark-packages in [default]
# 	net.sf.geographiclib#GeographicLib-Java;2.0 from central in [default]
# 	org.apache.spark#spark-avro_2.12;3.5.1 from central in [default]
# 	org.checkerframework#checker-qual;2.0.0 from central in [default]
# 	org.codehaus.mojo#animal-sniffer-annotations;1.14 from central in [default]
# 	org.ejml#ejml-core;0.43.1 from central in [default]
# 	org.ejml#ejml-ddense;0.43.1 from central in [default]
# 	org.mitre.spark#spark-geo-core_2.12;0.2.0 from repo-1 in [default]
# 	org.mitre.spark#spark-geo_spark3.5_2.12;0.2.0 from repo-1 in [default]
# 	org.mongodb#bson;4.8.2 from central in [default]
# 	org.mongodb#bson-record-codec;4.8.2 from central in [default]
# 	org.mongodb#mongodb-driver-core;4.8.2 from central in [default]
# 	org.mongodb#mongodb-driver-sync;4.8.2 from central in [default]
# 	org.mongodb.spark#mongo-spark-connector_2.12;10.3.0 from central in [default]
# 	org.scala-lang.modules#scala-collection-compat_2.12;2.11.0 from central in [default]
# 	org.slf4j#slf4j-api;1.7.16 from central in [default]
# 	org.tukaani#xz;1.9 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   26  |   1   |   0   |   0   ||   26  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-493695c5-1a15-4bd3-bb1b-d6dd2312213c
# 	confs: [default]
# 	0 artifacts copied, 26 already retrieved (0kB/24ms)
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Setting Spark log level to "ERROR".

# %%
year0 = "2026"
year1 = str(int(year0) + 1)

# %%
dates = {"start_date": year0 + "-01-01", "end_date": year1 +"-01-01"}

# %% [raw]
# # retrieve sectors

# %%
df_airspaces = (
    api.dataframe("StaticEramAirspace",
                  **dates,
#                  partition_filters=api.custom_partitions(['ARTCC_SECTOR']), // additional: {FULLNAME -> SECT1} 
#                  partition_filters=api.custom_partitions(['SECTOR']), // additional: {ACTIVE -> false} or {ACTIVE -> true}
#                  partition_filters=api.custom_partitions(['TRACON']), // additional: {}
#                  partition_filters=api.custom_partitions(['SAA']), // additional: {ACTIVE -> ALWAYS_OFF, TYPE -> LOCAL_ASSIGNED}
#                  partition_filters=api.custom_partitions(['FAV']), # additional: {TYPE -> ENROUTE} ; {TYPE -> APPROACH, ARTSID -> MCI} ; 
#                  partition_filters=api.custom_partitions(['ZDC']),
                  partition_filters=api.custom_partitions(['ZDC', 'FAV']),
                  metadata=True)
#    .select(
#        F.col("metadata.custom_partitions").alias("partitions"),
#        F.col("metadata.effective_end_date").alias("end_date"),
#    )
    .withColumn("grouping", F.concat("center", F.lit("_"), "identifier", F.lit("_"), "type"))
)
# Out:
# Multiple versions found: 3.1.71, 3.1.73, 3.1.74, 3.1.76, 3.1.77, 3.1.79

# %%
df_airspaces.count()
# Out:
# 992

# %%
#df_sectors.show(100, truncate=False)

# %%
#window = Window.partitionBy("grouping").orderBy(col("end_date").desc())
#window = Window.partitionBy("grouping").orderBy(col("metadata.effective_end_date").desc())
window = Window.partitionBy("grouping").orderBy(col("chart_date").desc())

df_airspaces_newest = (df_airspaces
    .withColumn("row", row_number().over(window))
    .filter(col("row") == 1)
    .drop("row", "chart_date")
    .orderBy("grouping")
)

# %%
df_airspaces_newest.count()
# Out:
# 142

# %%
#df_airspaces_newest.select("type", "identifier", "additional").show(10, truncate=False)
#df_airspaces_newest.show(1, truncate=False)
test = (
    df_airspaces_newest
    .select("center", "type", "identifier", "additional")
    .withColumn("thing1", df_airspaces_newest["additional"].getItem("TYPE"))
    .withColumn("thing2", df_airspaces_newest["additional"].getItem("ARTSID"))
    ).show(142, truncate=False)
# Out:
# [Stage 91:=====================================================>(398 + 2) / 400]
# +------+----+----------+---------------------------------+--------+------+
# |center|type|identifier|additional                       |thing1  |thing2|
# +------+----+----------+---------------------------------+--------+------+
# |ZDC   |FAV |00101     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |00201     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |00301     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |00401     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |00501     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |00601     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |00701     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |00702     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |00801     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |00901     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |01001     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |01101     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |01201     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |01301     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |01401     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |01501     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |01502     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |01601     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |01701     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |01801     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |01901     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |02001     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |02101     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |02201     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |02301     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |02501     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |02601     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |02701     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |02801     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |02901     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |03050     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |03090     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |03101     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |03201     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |03202     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |03301     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |03401     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |03501     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |03601     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |03701     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |03702     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |03801     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |03901     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |04201     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |05001     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |05101     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |05201     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |05301     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |05401     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |05601     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |05801     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |05901     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |06001     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |06101     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |06301     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |06401     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |06501     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |07201     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |07901     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |07902     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |07903     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |07904     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |07905     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |07906     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |07907     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |07908     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |07909     |{TYPE -> ENROUTE}                |ENROUTE |NULL  |
# |ZDC   |FAV |08001     |{TYPE -> APPROACH, ARTSID -> ROA}|APPROACH|ROA   |
# |ZDC   |FAV |08002     |{TYPE -> APPROACH, ARTSID -> ROA}|APPROACH|ROA   |
# |ZDC   |FAV |08101     |{TYPE -> APPROACH}               |APPROACH|NULL  |
# |ZDC   |FAV |08102     |{TYPE -> APPROACH}               |APPROACH|NULL  |
# |ZDC   |FAV |08201     |{TYPE -> APPROACH, ARTSID -> RDU}|APPROACH|RDU   |
# |ZDC   |FAV |08601     |{TYPE -> APPROACH, ARTSID -> ORF}|APPROACH|ORF   |
# |ZDC   |FAV |08602     |{TYPE -> APPROACH, ARTSID -> ORF}|APPROACH|ORF   |
# |ZDC   |FAV |08701     |{TYPE -> APPROACH, ARTSID -> GSB}|APPROACH|GSB   |
# |ZDC   |FAV |08702     |{TYPE -> APPROACH, ARTSID -> GSB}|APPROACH|GSB   |
# |ZDC   |FAV |08703     |{TYPE -> APPROACH, ARTSID -> GSB}|APPROACH|GSB   |
# |ZDC   |FAV |08704     |{TYPE -> APPROACH, ARTSID -> GSB}|APPROACH|GSB   |
# |ZDC   |FAV |08712     |{TYPE -> APPROACH, ARTSID -> GSB}|APPROACH|GSB   |
# |ZDC   |FAV |08713     |{TYPE -> APPROACH, ARTSID -> GSB}|APPROACH|GSB   |
# |ZDC   |FAV |08714     |{TYPE -> APPROACH, ARTSID -> GSB}|APPROACH|GSB   |
# |ZDC   |FAV |08801     |{TYPE -> APPROACH, ARTSID -> NYG}|APPROACH|NYG   |
# |ZDC   |FAV |08901     |{TYPE -> APPROACH, ARTSID -> NTU}|APPROACH|NTU   |
# |ZDC   |FAV |09001     |{TYPE -> APPROACH, ARTSID -> ILM}|APPROACH|ILM   |
# |ZDC   |FAV |09101     |{TYPE -> APPROACH, ARTSID -> FAY}|APPROACH|FAY   |
# |ZDC   |FAV |09126     |{TYPE -> APPROACH, ARTSID -> FAY}|APPROACH|FAY   |
# |ZDC   |FAV |09127     |{TYPE -> APPROACH, ARTSID -> FAY}|APPROACH|FAY   |
# |ZDC   |FAV |09201     |{TYPE -> APPROACH, ARTSID -> NCA}|APPROACH|NCA   |
# |ZDC   |FAV |09301     |{TYPE -> APPROACH, ARTSID -> NKT}|APPROACH|NKT   |
# |ZDC   |FAV |09302     |{TYPE -> APPROACH, ARTSID -> NKT}|APPROACH|NKT   |
# |ZDC   |FAV |09401     |{TYPE -> APPROACH, ARTSID -> NHK}|APPROACH|NHK   |
# |ZDC   |FAV |09501     |{TYPE -> APPROACH, ARTSID -> ACY}|APPROACH|ACY   |
# |ZDC   |FAV |09601     |{TYPE -> APPROACH, ARTSID -> DOV}|APPROACH|DOV   |
# |ZDC   |FAV |09701     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09702     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09703     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09704     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09705     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09708     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09709     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09710     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09711     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09712     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09721     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09722     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09723     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09724     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09725     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09729     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09732     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09733     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09734     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09735     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09739     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09742     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09743     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09744     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09749     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09752     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09762     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09765     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09766     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09768     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09799     |{TYPE -> APPROACH, ARTSID -> NVF}|APPROACH|NVF   |
# |ZDC   |FAV |09902     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09903     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09904     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09905     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09906     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09907     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09908     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09909     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09911     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09912     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09913     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09914     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09915     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09916     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09917     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09918     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09919     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# |ZDC   |FAV |09920     |{TYPE -> APPROACH, ARTSID -> PCT}|APPROACH|PCT   |
# +------+----+----------+---------------------------------+--------+------+

# %%
df_tracons = (
    api.dataframe("StaticEramAirspace",
                  **dates,
                  partition_filters=api.custom_partitions(['ARTCC']),
                  metadata=True)
    .select (
        "type",
        "center",
        "identifier",
        "chart_date",
        F.explode('geometry.modules').alias('module')
    )
    .withColumnRenamed('center', 'artcc')
    .withColumnRenamed('identifier', 'tracon')
#    .filter(F.col("tracon") == "PWM")
    .withColumn("grouping", F.concat("artcc", F.lit("_"), "tracon", F.lit("_"), "module.identifier"))
    .orderBy("grouping")
)
# Out:
# Multiple versions found: 3.1.71, 3.1.73, 3.1.74, 3.1.76, 3.1.77, 3.1.79

# %%
df_tracons.count()
# Out:
# 9806

# %%
#df_tracons.show(1, truncate=False)
#df_tracons.show()

# %% [markdown]
# ## keep only the newest update

# %%
window = Window.partitionBy("grouping").orderBy(col("chart_date").desc())

df_tracons_newest = (df_tracons
    .withColumn("row", row_number().over(window))
    .filter(col("row") == 1)
    .drop("row", "chart_date")
    .orderBy("grouping")
)

# %%
df_tracons_newest.count()
# Out:
# 1457

# %%
#df_tracons_newest.show(10, truncate=False)
#df_tracons_newest.show(1, truncate=False)

# %%
module_schema = T.StructType([
    T.StructField("module", T.StructType([
        T.StructField("identifier", T.DoubleType(), True),
        T.StructField("floor", T.DoubleType(), True),
        T.StructField("ceiling", T.DoubleType(), True),
        T.StructField("polygon", T.StructType([
            T.StructField("boundary", T.ArrayType(
                T.StructType([
                    T.StructField("latitude", T.DoubleType(), True),
                    T.StructField("longitude", T.DoubleType(), True),
                    T.StructField("sequence_number", T.IntegerType(), True),
                ]), True), True),
        ]), True),
    ]), True),
])

# %%
none_string = "*"
separator_string = ":"

#@F.udf(T.StringType())
@F.udf(T.MapType(T.StringType(),T.StringType()))
def extract_boundary_from_module(module:module_schema) -> map:  
    result = {}

    result["shelf"] = f'{module.identifier}'
    result["floor"] = f'{module.floor:.0f}'
    result["ceiling"] = f'{module.ceiling:.0f}'

    boundary_string = ""

    module.polygon.boundary.sort(key=lambda x: x.sequence_number, reverse=False)

    for point in module.polygon.boundary:
        boundary_string += (none_string if point.latitude is None else f'{point.latitude:.6f}') + " "
        boundary_string += (none_string if point.longitude is None else f'{point.longitude:.6f}') + separator_string

    # drop the trailing separator
    if len(boundary_string) > 0:
        boundary_string = boundary_string[0:len(separator_string) * -1]

    result["boundary"] = boundary_string
    result["shelf"] = module.identifier

    return result

# %%
df_tracons_dict = (
    df_tracons_newest
    .withColumn("module_dict", extract_boundary_from_module("module"))
    .select(
        "type",
        "artcc",
        "tracon",
        "module_dict",
    )
    .drop("module")
    .orderBy("type", "artcc", "tracon")
)

# %%
#df_tracons_dict.show(1, truncate=False)

# %%
# expand the dictionary to columns

# https://mungingdata.com/pyspark/dict-map-to-multiple-columns/
# https://stackoverflow.com/questions/36869134/pyspark-converting-a-column-of-type-map-to-multiple-columns-in-a-dataframe

keys = ["shelf", "ceiling", "floor", "boundary"]
key_cols = list(map(lambda f: F.col("module_dict").getItem(f).alias(str(f)), keys))
final_cols = [
        "type",
        "center",
        "tracon",
             ] + key_cols

# %%
df_tracons_output = (
    df_tracons_dict.select(final_cols)
    .withColumnRenamed('boundary', 'geometry')
)

# %%
#df_tracons_output.show(10)

# %%
(
    df_tracons_output
    .write.option("header", True)
    .csv("CRAFT/" + year0 + "/tracons", compression="None", mode="overwrite")
)
