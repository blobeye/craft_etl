# %%
import cda2
import json
import re
import pyspark.sql.types as T
import pyspark.sql.functions as F
#import datetime
import time

from datetime import datetime, timedelta
from timeit import default_timer as timer
from pyspark.sql.window import Window
from pyspark.sql.functions import col, row_number

# %% [markdown]
# # Connect to Spark

# %%
api = cda2.Api()

# %% [markdown]
# Set configuration parameters to better optimize queries.

# %%
config = {
    "spark.sql.adaptive.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.parallelismFirst": "false",
    "spark.sql.adaptive.coalescePartitions.minPartitionSize": "1m",
    "spark.executor.memory": "8g",
    "spark.executor.memoryOverhead": "16g",
}

# %% [markdown]
# Start Spark and specify number of cpus to use. 400 is quite high, but we'll be running 1 year at a time and want to have it done in just a few minutes.

# %%
api.start_spark(n_executors=400, config=config)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/11/14 17:47:49 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/11/14 17:47:51 WARN DomainSocketFactory: The short-circuit local reads feature cannot be used because libhadoop cannot be loaded.
# 23/11/14 17:49:23 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Attempted to request executors before the AM has registered!

# %%
year0 = "2019"
year1 = str(int(year0) + 1)

# %%
datelist = [
    year0 + "0101",
    year0 + "0701",
    year1 + "0101",
]

datelist = [
    year0 + "0101",
    year0 + "0301",
    year0 + "0501",
    year0 + "0701",
    year0 + "0901",
    year0 + "1101",
    year1 + "0101",
]

datelist = [
    year0 + "0101",
    year0 + "0401",
    year0 + "0701",
    year0 + "1001",
    year0 + "1101",
    year0 + "1201",
    year1 + "0101",
]

datelist = [
    year0 + "0101",
    year0 + "0201",
    year0 + "0301",
    year0 + "0401",
    year0 + "0501",
    year0 + "0601",
    year0 + "0701",
    year0 + "0801",
    year0 + "0901",
    year0 + "1001",
    year0 + "1101",
    year0 + "1201",
    year1 + "0101",
]

# %%
i = 0;

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
# Out:
# start time:  2023-11-14 17:49:23.769125
# starting:  {'start_date': '20191101', 'end_date': '20191201'}
#    retrieving litetracks
# [Stage 0:>                                                          (0 + 0) / 1]
# 23/11/14 17:49:42 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:49:57 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:50:12 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:50:27 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# [Stage 0:>                                                          (0 + 0) / 1]
# 23/11/14 17:50:42 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:50:57 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:51:12 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:51:27 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# [Stage 0:>                                                          (0 + 0) / 1]
# 23/11/14 17:51:42 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:51:57 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:52:12 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:52:27 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# [Stage 0:>                                                          (0 + 0) / 1]
# 23/11/14 17:52:42 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:52:57 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:53:12 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:53:27 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# [Stage 0:>                                                          (0 + 0) / 1]
# 23/11/14 17:53:42 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:53:57 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:54:12 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:54:27 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# [Stage 0:>                                                          (0 + 0) / 1]
# 23/11/14 17:54:42 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:54:57 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:55:12 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 23/11/14 17:55:27 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# [Stage 0:>                                                          (0 + 0) / 1]
# 23/11/14 17:55:42 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
#    retrieving planned_routes
# Multiple versions found: 3.1.12.2, 3.1.22
#    retrieving flightplans
#    retrieving airspace_assignments
#    joining dataframes
#    creating master dataframe
#    started saving litetracks
#                                                                                 ]]
#    completed saving litetracks
#    started saving flightplans
#                                                                                 ]]]
#    completed saving flightplans
#    started saving airspace_assignments
# [Stage 238:>                                                        (0 + 1) / 1]1]0]]]
#    completed saving airspace_assignments
# end time:  2023-11-14 18:07:45.990078

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("start time: ", datetime.now())
    # %run "retrieve_traffic_v1.ipynb"
    i += 1
    print("end time: ", datetime.now())
