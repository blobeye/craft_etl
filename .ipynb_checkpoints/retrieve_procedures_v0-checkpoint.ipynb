# %% [markdown]
# # Imports

# %%
import cda2
#import datetime
import pyspark.sql.functions as F
import pyspark.sql.types as T
import json

from datetime import datetime, timedelta
from pyspark.sql.window import Window
from pyspark.sql.functions import col, row_number

# %% [markdown]
# # Connect to Spark

# %%
api = cda2.Api()

# %% [markdown]
# Set configuration parameters to better optimize queries.

# %%
config = {
    "spark.sql.adaptive.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.parallelismFirst": "false",
    "spark.sql.adaptive.coalescePartitions.minPartitionSize": "1m",
    "spark.executor.memory": "8g",
    "spark.executor.memoryOverhead": "16g",
}

# %% [markdown]
# Start Spark and specify number of cpus to use.

# %%
#api.start_spark(n_executors=100, config=config)
api.start_spark(n_executors=400)
# Out:
# https://artifacts.mitre.org/artifactory/java-libs-release added as a remote repository with the name: repo-1
# https://dali.mitre.org/nexus/content/repositories/mitre-caasd-releases added as a remote repository with the name: repo-2
# https://dali.mitre.org/nexus/content/repositories/external-releases added as a remote repository with the name: repo-3
# Ivy Default Cache set to: /home/rchong/.ivy2/cache
# The jars for the packages stored in: /home/rchong/.ivy2/jars
# org.mitre.spark#spark-geo_spark3.5_2.12 added as a dependency
# org.apache.spark#spark-avro_2.12 added as a dependency
# graphframes#graphframes added as a dependency
# org.mongodb.spark#mongo-spark-connector_2.12 added as a dependency
# com.oracle.database.jdbc#ojdbc8 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-5ac41a9e-70ea-49fd-b7c1-80ad98eefc1d;1.0
# 	confs: [default]
# :: loading settings :: url = jar:file:/devel/data_access/software/tdp-jupyter/poetry/cache/virtualenvs/python39-QwwvzYkJ-py3.9/lib/python3.9/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 	found org.mitre.spark#spark-geo_spark3.5_2.12;0.2.0 in repo-1
# 	found org.mitre.spark#spark-geo-core_2.12;0.2.0 in repo-1
# 	found org.scala-lang.modules#scala-collection-compat_2.12;2.11.0 in central
# 	found net.sf.geographiclib#GeographicLib-Java;2.0 in central
# 	found org.ejml#ejml-core;0.43.1 in central
# 	found org.ejml#ejml-ddense;0.43.1 in central
# 	found com.esri.geometry#esri-geometry-api;2.2.4 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.9.6 in central
# 	found com.google.geometry#s2-geometry;2.0.0 in central
# 	found com.google.guava#guava;25.1-jre in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found org.checkerframework#checker-qual;2.0.0 in central
# 	found com.google.errorprone#error_prone_annotations;2.1.3 in central
# 	found com.google.j2objc#j2objc-annotations;1.1 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.14 in central
# 	found com.uber#h3;4.1.1 in central
# 	found org.apache.spark#spark-avro_2.12;3.5.1 in central
# 	found org.tukaani#xz;1.9 in central
# 	found graphframes#graphframes;0.8.3-spark3.5-s_2.12 in spark-packages
# 	found org.slf4j#slf4j-api;1.7.16 in central
# 	found org.mongodb.spark#mongo-spark-connector_2.12;10.3.0 in central
# 	found org.mongodb#mongodb-driver-sync;4.8.2 in central
# 	[4.8.2] org.mongodb#mongodb-driver-sync;[4.8.1,4.8.99)
# 	found org.mongodb#bson;4.8.2 in central
# 	found org.mongodb#mongodb-driver-core;4.8.2 in central
# 	found org.mongodb#bson-record-codec;4.8.2 in central
# 	found com.oracle.database.jdbc#ojdbc8;23.4.0.24.05 in central
# :: resolution report :: resolve 3203ms :: artifacts dl 36ms
# 	:: modules in use:
# 	com.esri.geometry#esri-geometry-api;2.2.4 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.9.6 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.errorprone#error_prone_annotations;2.1.3 from central in [default]
# 	com.google.geometry#s2-geometry;2.0.0 from central in [default]
# 	com.google.guava#guava;25.1-jre from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.1 from central in [default]
# 	com.oracle.database.jdbc#ojdbc8;23.4.0.24.05 from central in [default]
# 	com.uber#h3;4.1.1 from central in [default]
# 	graphframes#graphframes;0.8.3-spark3.5-s_2.12 from spark-packages in [default]
# 	net.sf.geographiclib#GeographicLib-Java;2.0 from central in [default]
# 	org.apache.spark#spark-avro_2.12;3.5.1 from central in [default]
# 	org.checkerframework#checker-qual;2.0.0 from central in [default]
# 	org.codehaus.mojo#animal-sniffer-annotations;1.14 from central in [default]
# 	org.ejml#ejml-core;0.43.1 from central in [default]
# 	org.ejml#ejml-ddense;0.43.1 from central in [default]
# 	org.mitre.spark#spark-geo-core_2.12;0.2.0 from repo-1 in [default]
# 	org.mitre.spark#spark-geo_spark3.5_2.12;0.2.0 from repo-1 in [default]
# 	org.mongodb#bson;4.8.2 from central in [default]
# 	org.mongodb#bson-record-codec;4.8.2 from central in [default]
# 	org.mongodb#mongodb-driver-core;4.8.2 from central in [default]
# 	org.mongodb#mongodb-driver-sync;4.8.2 from central in [default]
# 	org.mongodb.spark#mongo-spark-connector_2.12;10.3.0 from central in [default]
# 	org.scala-lang.modules#scala-collection-compat_2.12;2.11.0 from central in [default]
# 	org.slf4j#slf4j-api;1.7.16 from central in [default]
# 	org.tukaani#xz;1.9 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   26  |   1   |   0   |   0   ||   26  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-5ac41a9e-70ea-49fd-b7c1-80ad98eefc1d
# 	confs: [default]
# 	0 artifacts copied, 26 already retrieved (0kB/17ms)
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Setting Spark log level to "ERROR".

# %% [markdown]
# # Define global variables and functions

# %%
airports = [
    "KADW",
    "KATL",
    "KBOS",
    "KBWI",
    "KCLT",
    "KDCA",
    "KDEN",
    "KDFW",
    "KDTW",
    "KEWR",
    "KFLL",
    "KIAD",
    "KIAH",
    "KJFK",
    "KLAS",
    "KLAX",
    "KLGA",
    "KMCO",
    "KMDW",
    "KMEM",
    "KMIA",
    "KMSP",
    "KORD",
    "KPHL",
    "KPHX",
    "KSAN",
    "KSDF",
    "KSEA",
    "KSFO",
    "KSLC",
    "KTPA",
    "PANC",
    "PHNL",
]

# %% [markdown]
# Function to convert Unix timestamp (milliseconds from 1970) to YYYYMMDD string.

# %%
year0 = "2024"
year1 = str(int(year0) + 1)

# %%
dates = {"start_date": year0 + "-01-01", "end_date": year1 +"-01-01"}
print(dates)
# Out:
# {'start_date': '2024-01-01', 'end_date': '2025-01-01'}

# %%
print("retrieving procedures: ", datetime.now())
# Out:
# retrieving procedures:  2025-10-08 12:29:40.516445

# %% [markdown]
# # Retrieve SIDs and STARs for the airports of interest

# %% [markdown]
# <li>only get SID and STAR procedure types. (procedure_type = "APPROACH" is ignored)</li>
# <li>create a unique <i>grouping</i> column.</li>
# </br>
# this will retrieve multiple versions of each fix, one for each update cycle in the year.

# %%
xxx_df_procedures = (
    api.dataframe("ArincTransition", **dates, metadata=True)
    .select(
        "dtpp_procedure_name",
        "procedure_name",
        "procedure_type",
        "transition_name",
        "transition_type",
        F.col("airport.icao_region").alias("airport_icao_region"),
        F.col("airport.name").alias("airport"),
        F.explode("legs").alias("leg"),
        F.col("leg.path_terminator.identification.name").alias("fix_name"),
        F.col("leg.path_terminator.identification.icao_region").alias("fix_icao_region"),
        F.col("leg.sequence_number").alias("seq"),
        F.col("leg.path_terminator.latitude"),
        F.col("leg.path_terminator.longitude"),
        F.col("leg.path_terminator.magnetic_variation.modeled").alias("magnetic_variation"),
        F.col("leg.speed_limit.descriptor").alias("speed_description"),
        F.col("leg.speed_limit.limit").alias("speed_limit"),
        F.col("leg.speed_limit.altitude").alias("speed_altitude"),
        F.col("leg.altitude_limits.description").alias("altitude_description"),
        F.col("leg.altitude_limits.value1").alias("altitude_value1"),
        F.col("leg.altitude_limits.value2").alias("altitude_value2"),
        F.col("metadata.effective_end_date").alias("end_date"),
    )
    .withColumn("grouping", F.concat("procedure_name", F.lit("_"), "transition_name", F.lit("_"), "seq"))
#    .filter(F.col("grouping").isNotNull())
    .filter(F.col("dtpp_procedure_name").isNotNull())
    .filter(F.col("transition_name").isNotNull())
#    .filter(F.col("transition_name").isNotNull())
#    .filter(F.col("fix_name").isNotNull())
    .filter(F.col("procedure_type").isin("SID", "STAR"))
    .filter(F.col("airport_icao_region").startswith("K") | F.col("airport_icao_region").startswith("PA") | F.col("airport_icao_region").startswith("PH"))
#    comment the following out so we get procedures for all US airports
#    .filter(F.col("airport").isin(airports)) 
    .drop("leg")
    .orderBy("grouping")
)

xxx_df_procedures.count()

xxx_df_procedures.show(10)

# %%
stop

# %%
dates = {'start_date': '2023-01-01', 'end_date': '2024-01-01'}

df_procedures = (
    api.dataframe("ArincTransition", **dates, metadata=True)
    .select(
        "procedure_name",
        "transition_name",
        "procedure_type",
        "transition_type",
        F.col("airport.icao_region").alias("airport_icao_region"),
        F.col("airport.name").alias("airport"),
        F.explode("legs").alias("leg")
    )
    .withColumn("fix_name", F.col("leg.path_terminator.identification.name"))
#    .filter(F.col("fix_name").isNotNull())
    .filter(F.col("procedure_type").isin("SID", "STAR"))
    .filter(F.col("airport_icao_region").startswith("K") | F.col("airport_icao_region").startswith("PA") | F.col("airport_icao_region").startswith("PH"))
    .persist()
)
#df_procedures.show(10)
df_procedures.filter(F.col("fix_name").isNotNull()).show(10)
# Out:
# Multiple versions found: 3.1.49, 3.1.50, 3.1.51, 3.1.53, 3.1.54, 3.1.55, 3.1.58, 3.1.59, 3.1.60, 3.1.62, 3.1.63, 3.1.64
# +--------------+---------------+--------------+---------------+-------------------+-------+--------------------+--------+
# |procedure_name|transition_name|procedure_type|transition_type|airport_icao_region|airport|                 leg|fix_name|
# +--------------+---------------+--------------+---------------+-------------------+-------+--------------------+--------+
# |          77S2|           RW34|           SID|         COMMON|                 K1|   K77S|{5NPEQA8sCnAAAADA...|     EUG|
# |        AALLE3|           RW08|          STAR|         RUNWAY|                 K2|   KDEN|{5NPEQA8sCnAAAATA...|   HEDDD|
# |        AALLE3|           RW08|          STAR|         RUNWAY|                 K2|   KDEN|{5NPEQA8sCnAAAATA...|   DEELO|
# |        AALLE3|           RW08|          STAR|         RUNWAY|                 K2|   KDEN|{5NPEQA8sCnAAAATA...|   JEPHF|
# |        AALLE3|           RW08|          STAR|         RUNWAY|                 K2|   KDEN|{5NPEQA8sCnAAAATA...|   HAZLT|
# |        AALLE3|           RW08|          STAR|         RUNWAY|                 K2|   KDEN|{5NPEQA8sCnAAAATA...|   HAITR|
# |        AALLE3|           RW08|          STAR|         RUNWAY|                 K2|   KDEN|{5NPEQA8sCnAAAATA...|   HAITR|
# |        AALLE3|          RW16B|          STAR|         RUNWAY|                 K2|   KDEN|{5NPEQA8sCnAAAAUA...|   HEDDD|
# |        AALLE3|          RW16B|          STAR|         RUNWAY|                 K2|   KDEN|{5NPEQA8sCnAAAAUA...|   HIGUN|
# |        AALLE3|          RW16B|          STAR|         RUNWAY|                 K2|   KDEN|{5NPEQA8sCnAAAAUA...|   KIPPR|
# +--------------+---------------+--------------+---------------+-------------------+-------+--------------------+--------+
# only showing top 10 rows

# %%
dates = {'start_date': '2023-01-01', 'end_date': '2024-01-01'}

df_procedures = (
    api.dataframe("ArincTransition", **dates, metadata=True)
    .select(
        "dtpp_procedure_name",
        "procedure_name",
        "transition_name",
        "procedure_type",
        "transition_type",
        F.col("airport.icao_region").alias("airport_icao_region"),
        F.col("airport.name").alias("airport"),
        F.explode("legs").alias("leg"),
        F.col("metadata.effective_end_date").alias("end_date")
    )
    .withColumn("fix_name", F.col("leg.path_terminator.identification.name"))
    .withColumn("fix_icao_region", F.col("leg.path_terminator.identification.icao_region"))
    .withColumn("seq", F.col("leg.sequence_number").alias("seq"))
    .withColumn("latitude", F.col("leg.path_terminator.latitude"))
    .withColumn("longitude", F.col("leg.path_terminator.longitude"))
    .withColumn("magnetic_variation", F.col("leg.path_terminator.magnetic_variation.modeled"))
    .withColumn("speed_description", F.col("leg.speed_limit.descriptor"))
    .withColumn("speed_limit", F.col("leg.speed_limit.limit"))
    .withColumn("speed_altitude", F.col("leg.speed_limit.altitude"))
    .withColumn("altitude_description", F.col("leg.altitude_limits.description"))
    .withColumn("altitude_value1", F.col("leg.altitude_limits.value1"))
    .withColumn("altitude_value2", F.col("leg.altitude_limits.value2"))
    .withColumn("grouping", F.concat("procedure_name", F.lit("_"), "transition_name", F.lit("_"), "seq"))
    .filter(F.col("procedure_type").isin("SID", "STAR"))
    .filter(F.col("airport_icao_region").startswith("K") | F.col("airport_icao_region").startswith("PA") | F.col("airport_icao_region").startswith("PH"))
    .drop("leg")
    .orderBy("grouping")
    .persist()
)

df_procedures = (
    df_procedures
    .filter(F.col("grouping").isNotNull())
    .filter(F.col("transition_name").isNotNull())
    .filter(F.col("fix_name").isNotNull())
    .orderBy("grouping")
    .persist()
)

df_procedures.show(10)
# Out:
# Multiple versions found: 3.1.49, 3.1.50, 3.1.51, 3.1.53, 3.1.54, 3.1.55, 3.1.58, 3.1.59, 3.1.60, 3.1.62, 3.1.63, 3.1.64
# [Stage 524:==================================================>(1596 + 3) / 1600]
# +--------------------+--------------+---------------+--------------+---------------+-------------------+-------+-------------+--------+---------------+---+-----------------+-------------------+------------------+-----------------+-----------+--------------+--------------------+---------------+---------------+------------+
# | dtpp_procedure_name|procedure_name|transition_name|procedure_type|transition_type|airport_icao_region|airport|     end_date|fix_name|fix_icao_region|seq|         latitude|          longitude|magnetic_variation|speed_description|speed_limit|speed_altitude|altitude_description|altitude_value1|altitude_value2|    grouping|
# +--------------------+--------------+---------------+--------------+---------------+-------------------+-------+-------------+--------+---------------+---+-----------------+-------------------+------------------+-----------------+-----------+--------------+--------------------+---------------+---------------+------------+
# |                NULL|          1U71|           RW28|           SID|         RUNWAY|                 K1|   K1U7|1691625600000|   PAPIE|             K1| 20|42.46770277777778|-111.41303055555557|         11.024728|             NULL|       NULL|          NULL|         AT_OR_ABOVE|         8700.0|           NULL|1U71_RW28_20|
# |BEAR LAKE ONE (OB...|          1U71|           RW28|           SID|         RUNWAY|                 K1|    1U7|1701302400000|   PAPIE|             K1| 20|42.46770277777778|-111.41303055555557|         10.995691|             NULL|       NULL|          NULL|         AT_OR_ABOVE|         8700.0|           NULL|1U71_RW28_20|
# |                NULL|          1U71|           RW28|           SID|         RUNWAY|                 K1|   K1U7|1703721600000|   PAPIE|             K1| 20|42.46770277777778|-111.41303055555557|          10.98843|             NULL|       NULL|          NULL|         AT_OR_ABOVE|         8700.0|           NULL|1U71_RW28_20|
# |BEAR LAKE ONE (OB...|          1U71|           RW28|           SID|         RUNWAY|                 K1|    1U7|1698883200000|   PAPIE|             K1| 20|42.46770277777778|-111.41303055555557|         11.002952|             NULL|       NULL|          NULL|         AT_OR_ABOVE|         8700.0|           NULL|1U71_RW28_20|
# |BEAR LAKE ONE (OB...|          1U71|           RW28|           SID|         RUNWAY|                 K1|    1U7|1686787200000|   PAPIE|             K1| 20|42.46770277777778|-111.41303055555557|         11.039242|             NULL|       NULL|          NULL|         AT_OR_ABOVE|         8700.0|           NULL|1U71_RW28_20|
# |                NULL|          1U71|           RW28|           SID|         RUNWAY|                 K1|   K1U7|1686787200000|   PAPIE|             K1| 20|42.46770277777778|-111.41303055555557|         11.039242|             NULL|       NULL|          NULL|         AT_OR_ABOVE|         8700.0|           NULL|1U71_RW28_20|
# |BEAR LAKE ONE (OB...|          1U71|           RW28|           SID|         RUNWAY|                 K1|    1U7|1696464000000|   PAPIE|             K1| 20|42.46770277777778|-111.41303055555557|         11.010211|             NULL|       NULL|          NULL|         AT_OR_ABOVE|         8700.0|           NULL|1U71_RW28_20|
# |                NULL|          1U71|           RW28|           SID|         RUNWAY|                 K1|   K1U7|1698883200000|   PAPIE|             K1| 20|42.46770277777778|-111.41303055555557|         11.002952|             NULL|       NULL|          NULL|         AT_OR_ABOVE|         8700.0|           NULL|1U71_RW28_20|
# |BEAR LAKE ONE (OB...|          1U71|           RW28|           SID|         RUNWAY|                 K1|    1U7|1691625600000|   PAPIE|             K1| 20|42.46770277777778|-111.41303055555557|         11.024728|             NULL|       NULL|          NULL|         AT_OR_ABOVE|         8700.0|           NULL|1U71_RW28_20|
# |                NULL|          1U71|           RW28|           SID|         RUNWAY|                 K1|   K1U7|1701302400000|   PAPIE|             K1| 20|42.46770277777778|-111.41303055555557|         10.995691|             NULL|       NULL|          NULL|         AT_OR_ABOVE|         8700.0|           NULL|1U71_RW28_20|
# +--------------------+--------------+---------------+--------------+---------------+-------------------+-------+-------------+--------+---------------+---+-----------------+-------------------+------------------+-----------------+-----------+--------------+--------------------+---------------+---------------+------------+
# only showing top 10 rows

# %%
df_procedures.count()
# Out:
# 1928255

# %%
df_procedures = (
    api.dataframe("ArincTransition", **dates, metadata=True)
    .select(
        "dtpp_procedure_name",
        "procedure_name",
        "procedure_type",
        "transition_name",
        "transition_type",
        F.col("airport.icao_region").alias("airport_icao_region"),
        F.col("airport.name").alias("airport"),
        F.explode("legs").alias("leg"),
        F.col("leg.path_terminator.identification.name").alias("fix_name"),
        F.col("leg.path_terminator.identification.icao_region").alias("fix_icao_region"),
        F.col("leg.sequence_number").alias("seq"),
        F.col("leg.path_terminator.latitude"),
        F.col("leg.path_terminator.longitude"),
        F.col("leg.path_terminator.magnetic_variation.modeled").alias("magnetic_variation"),
        F.col("leg.speed_limit.descriptor").alias("speed_description"),
        F.col("leg.speed_limit.limit").alias("speed_limit"),
        F.col("leg.speed_limit.altitude").alias("speed_altitude"),
        F.col("leg.altitude_limits.description").alias("altitude_description"),
        F.col("leg.altitude_limits.value1").alias("altitude_value1"),
        F.col("leg.altitude_limits.value2").alias("altitude_value2"),
        F.col("metadata.effective_end_date").alias("end_date"),
    )
    .withColumn("grouping", F.concat("procedure_name", F.lit("_"), "transition_name", F.lit("_"), "seq"))
    .filter(F.col("transition_name").isNotNull())
    .filter(F.col("fix_name").isNotNull())
    .filter(F.col("procedure_type").isin("SID", "STAR"))
    .filter(F.col("airport_icao_region").startswith("K") | F.col("airport_icao_region").startswith("PA") | F.col("airport_icao_region").startswith("PH"))
#    comment the following out so we get procedures for all US airports
#    .filter(F.col("airport").isin(airports))
    .drop("leg")
    .orderBy("grouping")
)
#df_procedures.show(50)

# %%
dates = {'start_date': '2023-01-01', 'end_date': '2024-01-01'}

df_procedures_0 = (
    api.dataframe("ArincTransition", **dates, metadata=True)
    .select(
        "procedure_name",
        "transition_name",
        "procedure_type",
        "transition_type",
        F.col("airport.icao_region").alias("airport_icao_region"),
        F.col("airport.name").alias("airport"),
        F.explode("legs").alias("leg")
    )
    .filter(F.col("transition_name").isNotNull())
    .filter(F.col("procedure_type").isin("SID", "STAR"))
    .filter(F.col("airport_icao_region").startswith("K") | F.col("airport_icao_region").startswith("PA") | F.col("airport_icao_region").startswith("PH"))
    .persist()
)
df_procedures_0.show(10)

df_procedures_1 = (
    df_procedures_0
    .withColumn("fix_name", F.col("leg.path_terminator.identification.name"))
    .withColumn("seq", F.col("leg.sequence_number"))
    .withColumn("grouping", F.concat("procedure_name", F.lit("_"), "transition_name", F.lit("_"), "seq"))
    .drop("leg")
)
df_procedures_1.show(10)

df_procedures_2 = (
    df_procedures_1
    .filter(F.col("fix_name").isNotNull())
)
df_procedures_2.show(10)

# %%
# breaking it into two pieces and filtering on "grouping" seems to work?

# %%
df_procedures_0 = (
    api.dataframe("ArincTransition", **dates, metadata=True)
    .select(
        "dtpp_procedure_name",
        "procedure_name",
        "procedure_type",
        "transition_name",
        "transition_type",
        F.col("airport.icao_region").alias("airport_icao_region"),
        F.col("airport.name").alias("airport"),
        F.explode("legs").alias("leg"),
        F.col("leg.path_terminator.identification.name").alias("fix_name"),
        F.col("leg.path_terminator.identification.icao_region").alias("fix_icao_region"),
        F.col("leg.sequence_number").alias("seq"),
        F.col("leg.path_terminator.latitude"),
        F.col("leg.path_terminator.longitude"),
        F.col("leg.path_terminator.magnetic_variation.modeled").alias("magnetic_variation"),
        F.col("leg.speed_limit.descriptor").alias("speed_description"),
        F.col("leg.speed_limit.limit").alias("speed_limit"),
        F.col("leg.speed_limit.altitude").alias("speed_altitude"),
        F.col("leg.altitude_limits.description").alias("altitude_description"),
        F.col("leg.altitude_limits.value1").alias("altitude_value1"),
        F.col("leg.altitude_limits.value2").alias("altitude_value2"),
        F.col("metadata.effective_end_date").alias("end_date"),
    )
    .withColumn("grouping", F.concat("procedure_name", F.lit("_"), "transition_name", F.lit("_"), "seq"))
    .filter(F.col("procedure_type").isin("SID", "STAR"))
    .filter(F.col("airport_icao_region").startswith("K") | F.col("airport_icao_region").startswith("PA") | F.col("airport_icao_region").startswith("PH"))
    .drop("leg")
    .orderBy("grouping")
)
# df_procedures_0.show(10)

# %%
df_procedures = (
    df_procedures_step0
    .filter(F.col("grouping").isNotNull())
    .filter(F.col("transition_name").isNotNull())
    .filter(F.col("fix_name").isNotNull())
    .orderBy("grouping")
)
df_procedures.show(10)
# df_procedures_1.count()

# %%
stop

# %%
df_procedures = (
    api.dataframe("ArincTransition", **dates, metadata=True)
    .select(
        "dtpp_procedure_name",
        "procedure_name",
        "procedure_type",
        "transition_name",
        "transition_type",
        F.col("airport.icao_region").alias("airport_icao_region"),
        F.col("airport.name").alias("airport"),
        F.explode("legs").alias("leg"),
        F.col("leg.path_terminator.identification.name").alias("fix_name"),
        F.col("leg.path_terminator.identification.icao_region").alias("fix_icao_region"),
        F.col("leg.sequence_number").alias("seq"),
        F.col("leg.path_terminator.latitude"),
        F.col("leg.path_terminator.longitude"),
        F.col("leg.path_terminator.magnetic_variation.modeled").alias("magnetic_variation"),
        F.col("leg.speed_limit.descriptor").alias("speed_description"),
        F.col("leg.speed_limit.limit").alias("speed_limit"),
        F.col("leg.speed_limit.altitude").alias("speed_altitude"),
        F.col("leg.altitude_limits.description").alias("altitude_description"),
        F.col("leg.altitude_limits.value1").alias("altitude_value1"),
        F.col("leg.altitude_limits.value2").alias("altitude_value2"),
        F.col("metadata.effective_end_date").alias("end_date"),
    )
    .withColumn("grouping", F.concat("procedure_name", F.lit("_"), "transition_name", F.lit("_"), "seq"))
    .filter(F.col("transition_name").isNotNull())
    .filter(F.col("fix_name").isNotNull())
    .filter(F.col("procedure_type").isin("SID", "STAR"))
    .filter(F.col("airport_icao_region").startswith("K") | F.col("airport_icao_region").startswith("PA") | F.col("airport_icao_region").startswith("PH"))
#    comment the following out so we get procedures for all US airports
#    .filter(F.col("airport").isin(airports))
    .drop("leg")
    .orderBy("grouping")
)
#df_procedures.show(50)

# %% [markdown]
# ## keep only the newest update

# %%
window = Window.partitionBy("grouping").orderBy(col("end_date").desc())

df_procedures_newest = (df_procedures
    .withColumn("row", row_number().over(window))
    .filter(col("row") == 1)
    .drop("row", "end_date")
    .orderBy("grouping")
)

df_procedures_newest.count()
# Out:
# [Stage 436:============================================>          (17 + 4) / 21]
# 52825

# %% [markdown]
# ## output procedures (SIDs and STARs) partioned by airport

# %%
print("starting airport procedures: ", datetime.now())
# Out:
# starting airport procedures:  2025-10-08 13:24:06.356245

# %%
(
    df_procedures_newest
        .select(
            "dtpp_procedure_name",
            "procedure_name",
            "procedure_type",
            "transition_name",
            "transition_type",
            "fix_name",
            "fix_icao_region",
            "seq",
            "latitude",
            "longitude",
            "magnetic_variation",
            "airport",
            "speed_description",
            "speed_limit",
            "speed_altitude",
            "altitude_description",
            "altitude_value1",
            "altitude_value2"
        )
##        .orderBy("grouping")
        .repartition("airport")
        .write.option("header",True).partitionBy(["airport"])
        .csv("CRAFT/" + year0 + "/procedures", compression="None", mode="overwrite")
)

# %%
print("completed airport procedures: ", datetime.now())
# Out:
# completed airport procedures:  2025-10-08 13:24:26.534195

# %% [markdown]
# ## output all north american procedure fixes
# <li>add a column that concats all the procedures that use the fix</li>
# <li>add a column that concats the procedure types that use the fix</li>

# %%
print("starting aggregate procedures: ", datetime.now())
# Out:
# starting aggregate procedures:  2025-10-08 13:24:26.544686

# %%
(
    df_procedures_newest.groupBy("fix_name", "fix_icao_region", "latitude", "longitude", "magnetic_variation")
        .agg(F.concat_ws(":", F.collect_set("procedure_name")).alias("procedures_using_fix"), F.concat_ws(":", F.collect_set("procedure_type")).alias("procedure_types_using_fix"))
        .orderBy("fix_name")
        .write.option("header", True)
        .csv("CRAFT/" + year0 + "/procedures", compression="None", mode="append")
)

# %%
print("completed aggregate procedures: ", datetime.now())
# Out:
# completed aggregate procedures:  2025-10-08 13:24:31.233150

# %%
df_procedures.count()
# Out:
# 1928255

# %%
df_procedures_newest.count()
# Out:
# 52825
