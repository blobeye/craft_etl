# %%
import cda2
import json
import re
import pyspark.sql.types as T
import pyspark.sql.functions as F
#import datetime
import time

from datetime import datetime, timedelta
from timeit import default_timer as timer
from pyspark.sql.window import Window
from pyspark.sql.functions import col, row_number

# %% [markdown]
# # Connect to Spark

# %%
api = cda2.Api(timeout=120)

# %% [markdown]
# Set configuration parameters to better optimize queries.

# %%
config = {
    "spark.sql.adaptive.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.parallelismFirst": "false",
    "spark.sql.adaptive.coalescePartitions.minPartitionSize": "1m",
    "spark.executor.memory": "16g",
    "spark.executor.memoryOverhead": "16g",
    "spark.reducer.maxReqsInFlight": "1",
    "spark.shuffle.io.retryWait": "60s",
    "spark.shuffle.io.maxRetries": "10",
}

config = {
    # "spark.sql.adaptive.enabled": "true",
    # "spark.sql.adaptive.coalescePartitions.enabled": "true",
    # "spark.sql.adaptive.coalescePartitions.parallelismFirst": "false",
    # "spark.sql.adaptive.coalescePartitions.minPartitionSize": "1m",
    "spark.executor.memory": "16g",
    "spark.executor.memoryOverhead": "16g",
}

# %% [markdown]
# Start Spark and specify number of cpus to use. 400 is quite high, but we'll be running 1 year at a time and want to have it done in just a few minutes.

# %%
api.start_spark(n_executors=400, config=config)
#api.start_spark(n_executors=400)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/30 06:30:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/04/30 06:30:50 WARN DomainSocketFactory: The short-circuit local reads feature cannot be used because libhadoop cannot be loaded.
# 24/04/30 06:30:58 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Attempted to request executors before the AM has registered!

# %%
api.spark.sparkContext.setLogLevel("ERROR")

# %%
year0 = "2023"
year1 = str(int(year0) + 1)

# %%
datelist = [
    year0 + "0101",
    year1 + "0101",
]

datelist = [
    year0 + "0101",
    year0 + "0201",
    year0 + "0301",
    year0 + "0401",
    year0 + "0501",
    year0 + "0601",
    year0 + "0701",
    year0 + "0801",
    year0 + "0901",
    year0 + "1001",
    year0 + "1101",
    year0 + "1201",
    year1 + "0101",
]

datelist = [
    year0 + "0101",
    year0 + "0401",
    year0 + "0701",
    year0 + "1001",
    year1 + "0101",
]

# %%
script = "retrieve_traffic_v3.ipynb"

# %%
i = 0
do_litetracks = True
do_flightplans = True
do_airspace_assignments = True

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("dates: ", dates)
    print("start time: ", datetime.now())
    # %run $script
    i += 1
    print("end time: ", datetime.now())
# Out:
# dates:  {'start_date': '20230101', 'end_date': '20230401'}
# start time:  2024-04-30 06:31:20.441762
# starting:  {'start_date': '20230101', 'end_date': '20230401'}
# building track_key master list 2024-04-30 06:31:21.666942
#    getting df_flightplanseries_track_keys 2024-04-30 06:31:21.675104
# Multiple versions found: 3.1.51, 3.1.52, 3.1.53, 3.1.54, 3.1.64
#    getting df_plannedroutes_track_keys 2024-04-30 06:31:30.914005
# Multiple versions found: 3.1.51, 3.1.52, 3.1.53, 3.1.54, 3.1.65
#    getting df_airspaceassignments_track_keys 2024-04-30 06:31:35.352693
# Multiple versions found: 3.1.51, 3.1.52, 3.1.53, 3.1.54, 3.1.64
#    getting df_litetracks_track_keys 2024-04-30 06:32:51.097654
# Multiple versions found: 3.1.51, 3.1.53, 3.1.54, 3.1.55, 3.1.56, 3.1.64
# [Stage 12:(1504 + 13) / 1517][Stage 14:(1196 + 70) / 1612][Stage 17:=>(14 + 0) / 15]]]

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("dates: ", dates)
    print("start time: ", datetime.now())
    # %run $script
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("dates: ", dates)
    print("start time: ", datetime.now())
    # %run $script
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("dates: ", dates)
    print("start time: ", datetime.now())
    # %run $script
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("dates: ", dates)
    print("start time: ", datetime.now())
    # %run $script
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("dates: ", dates)
    print("start time: ", datetime.now())
    # %run $script
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("dates: ", dates)
    print("start time: ", datetime.now())
    # %run $script
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("dates: ", dates)
    print("start time: ", datetime.now())
    # %run $script
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("dates: ", dates)
    print("start time: ", datetime.now())
    # %run $script
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("dates: ", dates)
    print("start time: ", datetime.now())
    # %run $script
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("dates: ", dates)
    print("start time: ", datetime.now())
    # %run $script
    i += 1
    print("end time: ", datetime.now())

# %%
if i < len(datelist) - 1:
    dates = {"start_date": datelist[i], "end_date": datelist[i+1]}
    print("dates: ", dates)
    print("start time: ", datetime.now())
    # %run $script
    i += 1
    print("end time: ", datetime.now())
