# %% [markdown]
# <ul>

# %% [markdown]
# # 0. Imports

# %%
import cda2
import datetime
import pyspark.sql.functions as F
import pyspark.sql.types as T
import json
import re

from pyspark.sql.window import Window
from pyspark.sql.functions import col, row_number

# %% [markdown]
# # 1. Connect to Spark

# %%
api = cda2.Api()

# %% [markdown]
# Set configuration parameters to better optimize queries.

# %%
config = {
    "spark.sql.adaptive.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.enabled": "true",
    "spark.sql.adaptive.coalescePartitions.parallelismFirst": "false",
    "spark.sql.adaptive.coalescePartitions.minPartitionSize": "1m",
    "spark.executor.memory": "8g",
    "spark.executor.memoryOverhead": "16g",
}

# %% [markdown]
# Start Spark and specify number of cpus to use. 400 is quite high, but we'll be running 1 year at a time and want to have it done in just a few minutes.

# %%
api.start_spark(n_executors=400, config=config)
# Out:
# WARNING:cda2.api:Spark configuration for "spark.sql.shuffle.partitions" already set to "1600". Cannot overwrite.
# WARNING:cda2.api:Spark configuration for "spark.default.parallelism" already set to "1600". Cannot overwrite.

# %% [markdown]
# # 2. Define global variables and functions

# %%
year0 = "2019"
year1 = str(int(year0) + 1)

# %%
dates = {"start_date": year0 + "-01-01", "end_date": year1 +"-01-01"}

# %%
def get_alpha_portion(route_name:T.StringType) -> str:
    regex = "^([a-zA-Z]+)\d+"
    match = re.search(regex, route_name)
    if match:
        output = match.group(1)
    else:
        output = ""
    return output

get_alpha_portion_udf = F.udf(get_alpha_portion, T.StringType())

result = get_alpha_portion("AB100")
print(result)
# Out:
# AB

# %%
def get_numeric_portion(route_name:T.StringType) -> int:
    regex = "^[a-zA-Z]+(\d+)"
    match = re.search(regex, route_name)
    if match:
        output = int(match.group(1))
    else:
        output = null
    return output

get_numeric_portion_udf = F.udf(get_numeric_portion, T.StringType())

#result = get_numeric_portion("AB100")
#print(result)

# %%
def pad_seq_with_zeros(seq:T.IntegerType) -> str:
    output = str(seq).zfill(5)
    return output

pad_seq_with_zeros_udf = F.udf(pad_seq_with_zeros, T.StringType())

#result = pad_seq_with_zeros("170")
#print(result)

# %% [markdown]
# # 3. Retrieve all routes

# %% [markdown]
# <li>only get SID and STAR procedure types. (procedure_type = "APPROACH" is ignored)</li>
# <li>create a unique <i>grouping</i> column.</li>
# </br>
# this will retrieve multiple versions of each fix, one for each update cycle in the year.

# %%
df_routes_raw = (
    api.dataframe("ArincAirway", **dates, metadata=True)
    .select(
        F.col("identifier").alias("route"),
        F.col("arinc_record_info.customer_area_code").alias("area_code"),
#        "legs",
        F.explode("legs").alias("leg"),
        F.col("leg.path_terminator.identification.icao_region").alias("icao_region"),
        F.col("leg.path_terminator.identification.name").alias("fix_name"),
        F.col("leg.sequence_number").alias("seq"),
        F.col("metadata.effective_end_date").alias("end_date"),
        "path_terminators",
    )
    .withColumn("grouping", F.concat("route", F.lit("_"), "icao_region", F.lit("_"), pad_seq_with_zeros_udf("seq")))
    .withColumn("route_uniq", F.concat("route", F.lit("("), "area_code", F.lit("/"), "icao_region", F.lit(")")))
    .withColumn("fix_name_uniq", F.concat("fix_name", F.lit("("), "icao_region", F.lit(")")))
    .withColumn("alpha", get_alpha_portion_udf("route"))
    .withColumn("numeric", get_numeric_portion_udf("route").cast("int"))
    .filter(F.col("route") == "V35")
    .filter(F.col("area_code") == "USA")
#    .filter(F.col("icao_region") == "K6")
    .drop("legs", "leg")
#    .orderBy("grouping")
#    .orderBy("alpha", "numeric", "area_code", "icao_region", "seq")
)

#df_routes_raw.show()
#df_routes_raw.printSchema()
# Out:
# WARNING:cda2.api.models.partition:Multiple versions found: 3.1.12.2, 3.1.22

# %% [markdown]
# ## > keep only the newest update

# %%
window = Window.partitionBy("grouping").orderBy(col("end_date").desc())
#window = Window.partitionBy("route").orderBy(col("end_date").desc())

df_routes_newest = (df_routes_raw
    .withColumn("row", row_number().over(window))
    .filter(col("row") == 1)
    .drop("row")
#    .orderBy("alpha", "numeric", "area_code", "icao_region", "seq")
#    .orderBy("fix_name")
)

df_routes_newest.show(200)
# Out:
# [Stage 113:>                                                        (0 + 1) / 1]
# +-----+---------+-----------+--------+----+-------------+--------------------+------------+-----------+-------------+-----+-------+
# |route|area_code|icao_region|fix_name| seq|     end_date|    path_terminators|    grouping| route_uniq|fix_name_uniq|alpha|numeric|
# +-----+---------+-----------+--------+----+-------------+--------------------+------------+-----------+-------------+-----+-------+
# |  V35|      USA|         K6|     GZG| 480|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00480|V35(USA/K6)|      GZG(K6)|    V|     35|
# |  V35|      USA|         K6|   ZOMAD| 485|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00485|V35(USA/K6)|    ZOMAD(K6)|    V|     35|
# |  V35|      USA|         K6|   STACY| 490|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00490|V35(USA/K6)|    STACY(K6)|    V|     35|
# |  V35|      USA|         K6|   SLINK| 500|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00500|V35(USA/K6)|    SLINK(K6)|    V|     35|
# |  V35|      USA|         K6|   MACET| 510|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00510|V35(USA/K6)|    MACET(K6)|    V|     35|
# |  V35|      USA|         K6|   DIPUH| 515|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00515|V35(USA/K6)|    DIPUH(K6)|    V|     35|
# |  V35|      USA|         K6|     HVQ| 520|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00520|V35(USA/K6)|      HVQ(K6)|    V|     35|
# |  V35|      USA|         K6|   GLAZE| 530|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00530|V35(USA/K6)|    GLAZE(K6)|    V|     35|
# |  V35|      USA|         K6|   WARDO| 540|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00540|V35(USA/K6)|    WARDO(K6)|    V|     35|
# |  V35|      USA|         K6|   CARLA| 550|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00550|V35(USA/K6)|    CARLA(K6)|    V|     35|
# |  V35|      USA|         K6|   BENZO| 560|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00560|V35(USA/K6)|    BENZO(K6)|    V|     35|
# |  V35|      USA|         K6|     CKB| 570|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00570|V35(USA/K6)|      CKB(K6)|    V|     35|
# |  V35|      USA|         K6|     MGW| 580|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00580|V35(USA/K6)|      MGW(K6)|    V|     35|
# |  V35|      USA|         K6|     GZG| 620|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00620|V35(USA/K6)|      GZG(K6)|    V|     35|
# |  V35|      USA|         K6|     PSB| 630|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00630|V35(USA/K6)|      PSB(K6)|    V|     35|
# |  V35|      USA|         K6|   BLAZE| 640|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00640|V35(USA/K6)|    BLAZE(K6)|    V|     35|
# |  V35|      USA|         K6|     SFK| 650|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00650|V35(USA/K6)|      SFK(K6)|    V|     35|
# |  V35|      USA|         K6|   WUDUL| 655|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00655|V35(USA/K6)|    WUDUL(K6)|    V|     35|
# |  V35|      USA|         K6|     ULW| 660|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00660|V35(USA/K6)|      ULW(K6)|    V|     35|
# |  V35|      USA|         K6|   XUCCO| 663|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00663|V35(USA/K6)|    XUCCO(K6)|    V|     35|
# |  V35|      USA|         K6|   VAFKU| 664|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00664|V35(USA/K6)|    VAFKU(K6)|    V|     35|
# |  V35|      USA|         K6|   PTAKI| 665|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00665|V35(USA/K6)|    PTAKI(K6)|    V|     35|
# |  V35|      USA|         K6|   SCIPO| 670|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00670|V35(USA/K6)|    SCIPO(K6)|    V|     35|
# |  V35|      USA|         K6|     HVQ| 680|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00680|V35(USA/K6)|      HVQ(K6)|    V|     35|
# |  V35|      USA|         K6|     SYR| 690|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00690|V35(USA/K6)|      SYR(K6)|    V|     35|
# |  V35|      USA|         K6|   WARDO| 700|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00700|V35(USA/K6)|    WARDO(K6)|    V|     35|
# |  V35|      USA|         K6|   CARLA| 710|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00710|V35(USA/K6)|    CARLA(K6)|    V|     35|
# |  V35|      USA|         K6|   BENZO| 720|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00720|V35(USA/K6)|    BENZO(K6)|    V|     35|
# |  V35|      USA|         K6|     CKB| 730|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00730|V35(USA/K6)|      CKB(K6)|    V|     35|
# |  V35|      USA|         K6|     MGW| 740|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00740|V35(USA/K6)|      MGW(K6)|    V|     35|
# |  V35|      USA|         K6|     PSB| 750|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00750|V35(USA/K6)|      PSB(K6)|    V|     35|
# |  V35|      USA|         K6|   BLAZE| 760|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00760|V35(USA/K6)|    BLAZE(K6)|    V|     35|
# |  V35|      USA|         K6|     SFK| 770|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00770|V35(USA/K6)|      SFK(K6)|    V|     35|
# |  V35|      USA|         K6|   WUDUL| 780|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00780|V35(USA/K6)|    WUDUL(K6)|    V|     35|
# |  V35|      USA|         K6|     ULW| 790|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00790|V35(USA/K6)|      ULW(K6)|    V|     35|
# |  V35|      USA|         K6|   XUCCO| 800|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00800|V35(USA/K6)|    XUCCO(K6)|    V|     35|
# |  V35|      USA|         K6|   VAFKU| 810|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00810|V35(USA/K6)|    VAFKU(K6)|    V|     35|
# |  V35|      USA|         K6|   PTAKI| 820|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00820|V35(USA/K6)|    PTAKI(K6)|    V|     35|
# |  V35|      USA|         K6|   SCIPO| 830|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00830|V35(USA/K6)|    SCIPO(K6)|    V|     35|
# |  V35|      USA|         K6|     SYR| 840|1577923200000|DHP:CURVE:WORPP:D...|V35_K6_00840|V35(USA/K6)|      SYR(K6)|    V|     35|
# |  V35|      USA|         K7|     DHP|  40|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00040|V35(USA/K7)|      DHP(K7)|    V|     35|
# |  V35|      USA|         K7|   CURVE|  90|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00090|V35(USA/K7)|    CURVE(K7)|    V|     35|
# |  V35|      USA|         K7|   WORPP|  95|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00095|V35(USA/K7)|    WORPP(K7)|    V|     35|
# |  V35|      USA|         K7|   DEEDS| 100|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00100|V35(USA/K7)|    DEEDS(K7)|    V|     35|
# |  V35|      USA|         K7|   CORFU| 110|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00110|V35(USA/K7)|    CORFU(K7)|    V|     35|
# |  V35|      USA|         K7|     RSW| 120|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00120|V35(USA/K7)|      RSW(K7)|    V|     35|
# |  V35|      USA|         K7|   ERRIN| 125|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00125|V35(USA/K7)|    ERRIN(K7)|    V|     35|
# |  V35|      USA|         K7|   CEXAN| 128|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00128|V35(USA/K7)|    CEXAN(K7)|    V|     35|
# |  V35|      USA|         K7|   CHARO| 130|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00130|V35(USA/K7)|    CHARO(K7)|    V|     35|
# |  V35|      USA|         K7|   SABEE| 135|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00135|V35(USA/K7)|    SABEE(K7)|    V|     35|
# |  V35|      USA|         K7|   MURDO| 140|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00140|V35(USA/K7)|    MURDO(K7)|    V|     35|
# |  V35|      USA|         K7|   PAIRS| 150|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00150|V35(USA/K7)|    PAIRS(K7)|    V|     35|
# |  V35|      USA|         K7|   CARIR| 155|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00155|V35(USA/K7)|    CARIR(K7)|    V|     35|
# |  V35|      USA|         K7|     PIE| 160|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00160|V35(USA/K7)|      PIE(K7)|    V|     35|
# |  V35|      USA|         K7|   DONHU| 170|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00170|V35(USA/K7)|    DONHU(K7)|    V|     35|
# |  V35|      USA|         K7|   ENDED| 180|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00180|V35(USA/K7)|    ENDED(K7)|    V|     35|
# |  V35|      USA|         K7|   SABEE| 190|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00190|V35(USA/K7)|    SABEE(K7)|    V|     35|
# |  V35|      USA|         K7|   KAJYE| 200|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00200|V35(USA/K7)|    KAJYE(K7)|    V|     35|
# |  V35|      USA|         K7|   CEDDI| 210|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00210|V35(USA/K7)|    CEDDI(K7)|    V|     35|
# |  V35|      USA|         K7|     CTY| 220|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00220|V35(USA/K7)|      CTY(K7)|    V|     35|
# |  V35|      USA|         K7|     GEF| 230|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00230|V35(USA/K7)|      GEF(K7)|    V|     35|
# |  V35|      USA|         K7|   YALMI| 235|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00235|V35(USA/K7)|    YALMI(K7)|    V|     35|
# |  V35|      USA|         K7|   HARKE| 240|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00240|V35(USA/K7)|    HARKE(K7)|    V|     35|
# |  V35|      USA|         K7|   SALER| 250|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00250|V35(USA/K7)|    SALER(K7)|    V|     35|
# |  V35|      USA|         K7|     PZD| 260|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00260|V35(USA/K7)|      PZD(K7)|    V|     35|
# |  V35|      USA|         K7|   DESKS| 270|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00270|V35(USA/K7)|    DESKS(K7)|    V|     35|
# |  V35|      USA|         K7|   CAPAC| 275|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00275|V35(USA/K7)|    CAPAC(K7)|    V|     35|
# |  V35|      USA|         K7|   BAVCA| 280|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00280|V35(USA/K7)|    BAVCA(K7)|    V|     35|
# |  V35|      USA|         K7|   LILLY| 290|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00290|V35(USA/K7)|    LILLY(K7)|    V|     35|
# |  V35|      USA|         K7|   FRAUD| 300|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00300|V35(USA/K7)|    FRAUD(K7)|    V|     35|
# |  V35|      USA|         K7|   BOSAY| 305|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00305|V35(USA/K7)|    BOSAY(K7)|    V|     35|
# |  V35|      USA|         K7|   PHYLL| 310|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00310|V35(USA/K7)|    PHYLL(K7)|    V|     35|
# |  V35|      USA|         K7|   METER| 320|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00320|V35(USA/K7)|    METER(K7)|    V|     35|
# |  V35|      USA|         K7|     MCN| 330|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00330|V35(USA/K7)|      MCN(K7)|    V|     35|
# |  V35|      USA|         K7|   SINCA| 340|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00340|V35(USA/K7)|    SINCA(K7)|    V|     35|
# |  V35|      USA|         K7|   GLOSS| 350|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00350|V35(USA/K7)|    GLOSS(K7)|    V|     35|
# |  V35|      USA|         K7|   MADDI| 360|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00360|V35(USA/K7)|    MADDI(K7)|    V|     35|
# |  V35|      USA|         K7|   JOTNO| 363|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00363|V35(USA/K7)|    JOTNO(K7)|    V|     35|
# |  V35|      USA|         K7|   DACHA| 365|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00365|V35(USA/K7)|    DACHA(K7)|    V|     35|
# |  V35|      USA|         K7|     AHN| 370|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00370|V35(USA/K7)|      AHN(K7)|    V|     35|
# |  V35|      USA|         K7|   BOWMN| 372|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00372|V35(USA/K7)|    BOWMN(K7)|    V|     35|
# |  V35|      USA|         K7|   HARTI| 375|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00375|V35(USA/K7)|    HARTI(K7)|    V|     35|
# |  V35|      USA|         K7|     ELW| 380|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00380|V35(USA/K7)|      ELW(K7)|    V|     35|
# |  V35|      USA|         K7|   ELLID| 390|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00390|V35(USA/K7)|    ELLID(K7)|    V|     35|
# |  V35|      USA|         K7|   PEDAL| 400|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00400|V35(USA/K7)|    PEDAL(K7)|    V|     35|
# |  V35|      USA|         K7|   CLEVA| 410|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00410|V35(USA/K7)|    CLEVA(K7)|    V|     35|
# |  V35|      USA|         K7|   DOODD| 415|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00415|V35(USA/K7)|    DOODD(K7)|    V|     35|
# |  V35|      USA|         K7|   TUXDO| 420|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00420|V35(USA/K7)|    TUXDO(K7)|    V|     35|
# |  V35|      USA|         K7|     SUG| 430|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00430|V35(USA/K7)|      SUG(K7)|    V|     35|
# |  V35|      USA|         K7|   BUSIC| 440|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00440|V35(USA/K7)|    BUSIC(K7)|    V|     35|
# |  V35|      USA|         K7|   ROANS| 450|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00450|V35(USA/K7)|    ROANS(K7)|    V|     35|
# |  V35|      USA|         K7|     HMV| 460|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00460|V35(USA/K7)|      HMV(K7)|    V|     35|
# |  V35|      USA|         K7|   DACHA| 470|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00470|V35(USA/K7)|    DACHA(K7)|    V|     35|
# |  V35|      USA|         K7|     AHN| 480|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00480|V35(USA/K7)|      AHN(K7)|    V|     35|
# |  V35|      USA|         K7|   JOSPI| 490|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00490|V35(USA/K7)|    JOSPI(K7)|    V|     35|
# |  V35|      USA|         K7|   BOWMN| 500|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00500|V35(USA/K7)|    BOWMN(K7)|    V|     35|
# |  V35|      USA|         K7|   HARTI| 510|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00510|V35(USA/K7)|    HARTI(K7)|    V|     35|
# |  V35|      USA|         K7|     ELW| 520|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00520|V35(USA/K7)|      ELW(K7)|    V|     35|
# |  V35|      USA|         K7|   ELLID| 530|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00530|V35(USA/K7)|    ELLID(K7)|    V|     35|
# |  V35|      USA|         K7|   PEDAL| 540|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00540|V35(USA/K7)|    PEDAL(K7)|    V|     35|
# |  V35|      USA|         K7|   CLEVA| 550|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00550|V35(USA/K7)|    CLEVA(K7)|    V|     35|
# |  V35|      USA|         K7|   DOODD| 560|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00560|V35(USA/K7)|    DOODD(K7)|    V|     35|
# |  V35|      USA|         K7|   TUXDO| 570|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00570|V35(USA/K7)|    TUXDO(K7)|    V|     35|
# |  V35|      USA|         K7|     SUG| 580|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00580|V35(USA/K7)|      SUG(K7)|    V|     35|
# |  V35|      USA|         K7|   BUSIC| 590|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00590|V35(USA/K7)|    BUSIC(K7)|    V|     35|
# |  V35|      USA|         K7|   ROANS| 600|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00600|V35(USA/K7)|    ROANS(K7)|    V|     35|
# |  V35|      USA|         K7|     HMV| 610|1577923200000|DHP:CURVE:WORPP:D...|V35_K7_00610|V35(USA/K7)|      HMV(K7)|    V|     35|
# |  V35|      USA|         LF|   MEDUS|6100|1577923200000|MEDUS:CUERS:BIRGO...|V35_LF_06100|V35(USA/LF)|    MEDUS(LF)|    V|     35|
# |  V35|      USA|         LF|   CUERS|6110|1577923200000|MEDUS:CUERS:BIRGO...|V35_LF_06110|V35(USA/LF)|    CUERS(LF)|    V|     35|
# |  V35|      USA|         LF|   BIRGO|6120|1577923200000|MEDUS:CUERS:BIRGO...|V35_LF_06120|V35(USA/LF)|    BIRGO(LF)|    V|     35|
# |  V35|      USA|         LF|   GILON|6130|1577923200000|MEDUS:CUERS:BIRGO...|V35_LF_06130|V35(USA/LF)|    GILON(LF)|    V|     35|
# |  V35|      USA|         MM|     MTY|2600|1577923200000| MTY:EMAKI:DOTOR:REX|V35_MM_02600|V35(USA/MM)|      MTY(MM)|    V|     35|
# |  V35|      USA|         MM|   EMAKI|2605|1577923200000| MTY:EMAKI:DOTOR:REX|V35_MM_02605|V35(USA/MM)|    EMAKI(MM)|    V|     35|
# |  V35|      USA|         MM|   DOTOR|2610|1577923200000| MTY:EMAKI:DOTOR:REX|V35_MM_02610|V35(USA/MM)|    DOTOR(MM)|    V|     35|
# |  V35|      USA|         MM|     REX|2620|1577923200000| MTY:EMAKI:DOTOR:REX|V35_MM_02620|V35(USA/MM)|      REX(MM)|    V|     35|
# |  V35|      USA|         RJ|     KSE|3110|1577923200000|KSE:CRANE:TROUT:A...|V35_RJ_03110|V35(USA/RJ)|      KSE(RJ)|    V|     35|
# |  V35|      USA|         RJ|   CRANE|3115|1577923200000|KSE:CRANE:TROUT:A...|V35_RJ_03115|V35(USA/RJ)|    CRANE(RJ)|    V|     35|
# |  V35|      USA|         RJ|   TROUT|3120|1577923200000|KSE:CRANE:TROUT:A...|V35_RJ_03120|V35(USA/RJ)|    TROUT(RJ)|    V|     35|
# |  V35|      USA|         RJ|   AKESI|3125|1577923200000|KSE:CRANE:TROUT:A...|V35_RJ_03125|V35(USA/RJ)|    AKESI(RJ)|    V|     35|
# |  V35|      USA|         RJ|   ERIMO|3130|1577923200000|KSE:CRANE:TROUT:A...|V35_RJ_03130|V35(USA/RJ)|    ERIMO(RJ)|    V|     35|
# |  V35|      USA|         RJ|   ALICE|3140|1577923200000|KSE:CRANE:TROUT:A...|V35_RJ_03140|V35(USA/RJ)|    ALICE(RJ)|    V|     35|
# |  V35|      USA|         RJ|   LIDEL|3145|1577923200000|KSE:CRANE:TROUT:A...|V35_RJ_03145|V35(USA/RJ)|    LIDEL(RJ)|    V|     35|
# |  V35|      USA|         RJ|     MQE|3150|1577923200000|KSE:CRANE:TROUT:A...|V35_RJ_03150|V35(USA/RJ)|      MQE(RJ)|    V|     35|
# |  V35|      USA|         VH|   DOTMI|5500|1570665600000|DOTMI:JCS:UH:HOTO...|V35_VH_05500|V35(USA/VH)|    DOTMI(VH)|    V|     35|
# |  V35|      USA|         VO|     MML|7600|1577923200000|           MML:MUDIT|V35_VO_07600|V35(USA/VO)|      MML(VO)|    V|     35|
# |  V35|      USA|         VO|   MUDIT|7610|1577923200000|           MML:MUDIT|V35_VO_07610|V35(USA/VO)|    MUDIT(VO)|    V|     35|
# |  V35|      USA|         YM|   WONYU|4100|1577923200000|           WONYU:NWN|V35_YM_04100|V35(USA/YM)|    WONYU(YM)|    V|     35|
# |  V35|      USA|         YM|     NWN|4110|1577923200000|           WONYU:NWN|V35_YM_04110|V35(USA/YM)|      NWN(YM)|    V|     35|
# |  V35|      USA|         ZG|   DOTMI|5500|1577923200000|DOTMI:JCS:UH:HOTO...|V35_ZG_05500|V35(USA/ZG)|    DOTMI(ZG)|    V|     35|
# |  V35|      USA|         ZG|     JCS|5510|1577923200000|DOTMI:JCS:UH:HOTO...|V35_ZG_05510|V35(USA/ZG)|      JCS(ZG)|    V|     35|
# |  V35|      USA|         ZM|      UH|5700|1577923200000|DOTMI:JCS:UH:HOTO...|V35_ZM_05700|V35(USA/ZM)|       UH(ZM)|    V|     35|
# |  V35|      USA|         ZM|   HOTOL|5710|1577923200000|DOTMI:JCS:UH:HOTO...|V35_ZM_05710|V35(USA/ZM)|    HOTOL(ZM)|    V|     35|
# |  V35|      USA|         ZM|   TAMSA|5720|1577923200000|DOTMI:JCS:UH:HOTO...|V35_ZM_05720|V35(USA/ZM)|    TAMSA(ZM)|    V|     35|
# +-----+---------+-----------+--------+----+-------------+--------------------+------------+-----------+-------------+-----+-------+

# %%
#df_routes_newest.show(truncate=False)

# %% [markdown]
# ## > output all routes

# %%
df_routes_output = (
    df_routes_newest
        .withColumn("id", F.monotonically_increasing_id())
        .groupBy("route_uniq", "route", "alpha", "numeric", "area_code", "icao_region")
        .agg(F.concat_ws(":", F.collect_list("fix_name")).alias("fix_names"), F.concat_ws(":", F.collect_list("fix_name_uniq")).alias("uniq_fix_names"))
        .orderBy("alpha", "numeric", "area_code", "icao_region")
)

df_routes_output.write.option("header", True).csv("CRAFT/" + year0 + "/routes/all_routes", compression="None", mode="overwrite")

#df_routes_output.show()

# %% [markdown]
# # ------------------------------------

# %% [markdown]
# # 4. retrieve fixes

# %%
df_fixes_raw = (
    api.dataframe("ArincFix", **dates, metadata=True)
    .withColumn("fix_name_uniq", F.concat("identification.name", F.lit("("), "identification.icao_region", F.lit(")")))
    .select(
        "fix_name_uniq",
        F.col("identification.name").alias("fix_name"),
        F.col("arinc_record_info.customer_area_code").alias("area_code"),
        F.col("identification.icao_region").alias("icao_region"),
        "latitude",
        "longitude",
        F.col("magnetic_variation.modeled").alias("magnetic_variation"),
        F.col("metadata.effective_end_date").alias("end_date"),
    )
)

#df_fixes_raw.show()
# Out:
# Multiple versions found: 3.1.12.2, 3.1.22

# %%
df_fixes_raw.show()
# Out:
# [Stage 43:>                                                         (0 + 1) / 1]
# +-------------+--------+---------+-----------+------------------+-------------------+------------------+-------------+
# |fix_name_uniq|fix_name|area_code|icao_region|          latitude|          longitude|magnetic_variation|     end_date|
# +-------------+--------+---------+-----------+------------------+-------------------+------------------+-------------+
# |    00HNL(PH)|   00HNL|      PAC|         PH|19.935016666666666| -158.9449972222222|           9.25658|1573084800000|
# |    00LIH(PH)|   00LIH|      PAC|         PH|23.348605555555555|-160.35078333333334|          9.432852|1573084800000|
# |    00MKK(PH)|   00MKK|      PAC|         PH|22.537972222222223|-156.18695833333334|          9.644499|1573084800000|
# |    23LIH(PH)|   23LIH|      PAC|         PH| 23.66581111111111|-160.58662777777778|           9.43936|1573084800000|
# |    50MKK(PH)|   50MKK|      PAC|         PH|23.235561111111114| -155.6893638888889|          9.754545|1573084800000|
# |       AA(K7)|      AA|      USA|         K7| 33.53328333333333| -82.61436944444443|        -6.4497495|1573084800000|
# |       AA(K3)|      AA|      USA|         K3|47.009169444444446| -96.81517222222222|         2.7856655|1573084800000|
# |       AA(K3)|      AA|      USA|         K3|47.009052777777775| -96.81518333333334|         2.7856815|1573084800000|
# |      AAA(K5)|     AAA|      USA|         K5| 40.16011666666667| -89.33801666666666|        -2.4975977|1573084800000|
# |    AAALL(K6)|   AAALL|      USA|         K6| 42.12018888888889| -71.14176111111112|        -14.449091|1573084800000|
# |    AAAME(K2)|   AAAME|      USA|         K2| 37.77090833333333|-122.08281111111111|         13.275979|1573084800000|
# |    AAARN(K7)|   AAARN|      USA|         K7| 34.28149722222222| -85.26817222222222|        -4.7541146|1573084800000|
# |    AAAXX(K4)|   AAAXX|      USA|         K4|29.895705555555555| -95.39247222222222|         2.2903337|1573084800000|
# |    AABEE(K7)|   AABEE|      USA|         K7| 34.06805555555556|  -84.2143638888889|        -5.4493403|1573084800000|
# |    AABER(K7)|   AABER|      USA|         K7|26.072777777777777|             -81.33|        -6.2240443|1573084800000|
# |    AABEZ(K3)|   AABEZ|      USA|         K3| 44.78808333333333|  -93.0047111111111|       -0.11237814|1573084800000|
# |    AACES(K4)|   AACES|      USA|         K4| 35.27208611111111|  -97.1444388888889|         3.2955034|1573084800000|
# |     AACEZ(K)|   AACEZ|      USA|          K| 34.55277777777778| -73.99666666666667|        -11.670814|1573084800000|
# |    AADEN(K7)|   AADEN|      USA|         K7|31.541133333333335| -82.92853055555555|          -5.96701|1573084800000|
# |    AADIE(K5)|   AADIE|      USA|         K5| 39.88709166666666| -86.49233333333333|        -4.6192036|1573084800000|
# +-------------+--------+---------+-----------+------------------+-------------------+------------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ## > keep only the newest update

# %%
window = Window.partitionBy("fix_name_uniq").orderBy(col("end_date").desc())

df_fixes_newest = (df_fixes_raw
    .withColumn("row", row_number().over(window))
    .filter(col("row") == 1)
    .drop("row", "end_date")
    .orderBy("fix_name_uniq")
)

#df_fixes_newest.show()

# %%
df_routes_stripped = (
    df_routes_newest
    .select(
        "route",
        "route_uniq",
        "fix_name_uniq",
    )
)

#df_routes_stripped.show()

# %%
df_route_fixes = (
    df_fixes_newest
    .join(df_routes_stripped, on=["fix_name_uniq"], how="inner")
    .orderBy("fix_name_uniq", "route_uniq")
)

#df_route_fixes.show()

# %%
df_route_fixes_output = (
    df_route_fixes
        .groupBy("fix_name_uniq", "fix_name", "area_code", "icao_region", "latitude", "longitude", "magnetic_variation")
        .agg(F.concat_ws(":", F.collect_list("route")).alias("routes"), F.concat_ws(":", F.collect_list("route_uniq")).alias("routes_uniq_using_fix"))
        .orderBy("fix_name_uniq")
)

df_route_fixes_output.write.option("header", True).csv("CRAFT/" + year0 + "/routes/all_route_fixes", compression="None", mode="overwrite")

#df_route_fixes_output.show()
# Out:
#                                                                                 ]]
